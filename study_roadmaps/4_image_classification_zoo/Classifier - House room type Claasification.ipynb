# %% [markdown]
# <a href="https://colab.research.google.com/github/Tessellate-Imaging/monk_v1/blob/master/study_roadmaps/4_image_classification_zoo/Classifier%20-%20House%20room%20type%20Claasification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Goals
#
#
# ## Install Monk
#
#
# ## Using pretrained model for part of house classification dataset
#
#
# ## Training a classifier using default params
#
#   - Train a part of house classifier using resnet variants
#
#   - Understand what all differences happen when switching between resnets variants
#
#   - Understand bigger and deeper network not always means better results
#
#   - For this experiment you will be using mxnet backend

# %% [markdown]
# # Install Monk

# %% [markdown]
# ## Using pip (Recommended)
#
#   - colab (gpu)
#       - All bakcends: `pip install -U monk-colab`
#
#
#   - kaggle (gpu)
#       - All backends: `pip install -U monk-kaggle`
#
#
#   - cuda 10.2
#       - All backends: `pip install -U monk-cuda102`
#       - Gluon bakcned: `pip install -U monk-gluon-cuda102`
# 	  - Pytorch backend: `pip install -U monk-pytorch-cuda102`
#       - Keras backend: `pip install -U monk-keras-cuda102`
#
#
#   - cuda 10.1
#       - All backend: `pip install -U monk-cuda101`
# 	  - Gluon bakcned: `pip install -U monk-gluon-cuda101`
# 	  - Pytorch backend: `pip install -U monk-pytorch-cuda101`
# 	  - Keras backend: `pip install -U monk-keras-cuda101`
#
#
#   - cuda 10.0
#       - All backend: `pip install -U monk-cuda100`
# 	  - Gluon bakcned: `pip install -U monk-gluon-cuda100`
# 	  - Pytorch backend: `pip install -U monk-pytorch-cuda100`
# 	  - Keras backend: `pip install -U monk-keras-cuda100`
#
#
#   - cuda 9.2
#       - All backend: `pip install -U monk-cuda92`
# 	  - Gluon bakcned: `pip install -U monk-gluon-cuda92`
# 	  - Pytorch backend: `pip install -U monk-pytorch-cuda92`
# 	  - Keras backend: `pip install -U monk-keras-cuda92`
#
#
#   - cuda 9.0
#       - All backend: `pip install -U monk-cuda90`
# 	  - Gluon bakcned: `pip install -U monk-gluon-cuda90`
# 	  - Pytorch backend: `pip install -U monk-pytorch-cuda90`
# 	  - Keras backend: `pip install -U monk-keras-cuda90`
#
#
#   - cpu
#       - All backend: `pip install -U monk-cpu`
# 	  - Gluon bakcned: `pip install -U monk-gluon-cpu`
# 	  - Pytorch backend: `pip install -U monk-pytorch-cpu`
# 	  - Keras backend: `pip install -U monk-keras-cpu`

# %% [markdown]
# ## Install Monk Manually (Not recommended)
#
# ### Step 1: Clone the library
#  - git clone https://github.com/Tessellate-Imaging/monk_v1.git
#
#
#
#
# ### Step 2: Install requirements
#  - Linux
#      - Cuda 9.0
#          - `cd monk_v1/installation/Linux && pip install -r requirements_cu90.txt`
#      - Cuda 9.2
#          - `cd monk_v1/installation/Linux && pip install -r requirements_cu92.txt`
#      - Cuda 10.0
#          - `cd monk_v1/installation/Linux && pip install -r requirements_cu100.txt`
#      - Cuda 10.1
#          - `cd monk_v1/installation/Linux && pip install -r requirements_cu101.txt`
#      - Cuda 10.2
#          - `cd monk_v1/installation/Linux && pip install -r requirements_cu102.txt`
#      - CPU (Non gpu system)
#          - `cd monk_v1/installation/Linux && pip install -r requirements_cpu.txt`
#
#
#   - Windows
#      - Cuda 9.0 (Experimental support)
#          - `cd monk_v1/installation/Windows && pip install -r requirements_cu90.txt`
#      - Cuda 9.2 (Experimental support)
#          - `cd monk_v1/installation/Windows && pip install -r requirements_cu92.txt`
#      - Cuda 10.0 (Experimental support)
#          - `cd monk_v1/installation/Windows && pip install -r requirements_cu100.txt`
#      - Cuda 10.1 (Experimental support)
#          - `cd monk_v1/installation/Windows && pip install -r requirements_cu101.txt`
#      - Cuda 10.2 (Experimental support)
#          - `cd monk_v1/installation/Windows && pip install -r requirements_cu102.txt`
#      - CPU (Non gpu system)
#          - `cd monk_v1/installation/Windows && pip install -r requirements_cpu.txt`
#
#
#   - Mac
#      - CPU (Non gpu system)
#          - `cd monk_v1/installation/Mac && pip install -r requirements_cpu.txt`
#
#
#   - Misc
#       - Colab (GPU)
#           - `cd monk_v1/installation/Misc && pip install -r requirements_colab.txt`
#       - Kaggle (GPU)
#           - `cd monk_v1/installation/Misc && pip install -r requirements_kaggle.txt`
#
#
#
# ### Step 3: Add to system path (Required for every terminal or kernel run)
#  - `import sys`
#  - `sys.path.append("monk_v1/");`

# %% [markdown]
# # Used trained classifier for demo

# %%
#Using mxnet-gluon backend 

# When installed using pip
from monk.gluon_prototype import prototype


# When installed manually (Uncomment the following)
#import os
#import sys
#sys.path.append("monk_v1/");
#sys.path.append("monk_v1/monk/");
#from monk.gluon_prototype import prototype

# %%
#Download trained weights

# %%
! wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=10SrowcOJp8GWqEB21BfCIinqUCHS7PMv' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=10SrowcOJp8GWqEB21BfCIinqUCHS7PMv" -O cls_house_scene_trained.zip && rm -rf /tmp/cookies.txt

# %%
! unzip -qq cls_house_scene_trained.zip

# %%
ls workspace/Task
# Out:
# gluon-resnet18_v2/  gluon_resnet18_v1/
# gluon-resnet34_v1/  gluon_resnet18_v1_train_all_layers/

# %%
# Load project in inference mode

gtf = prototype(verbose=1);
gtf.Prototype("Task", "gluon_resnet18_v1_train_all_layers", eval_infer=True);

#Other trained models - uncomment 
#gtf.Prototype("Task", "gluon_resnet18_v1", eval_infer=True);
#gtf.Prototype("Task", "gluon-resnet18_v2", eval_infer=True);
#gtf.Prototype("Task", "gluon-resnet34_v1", eval_infer=True);
# Out:
# Mxnet Version: 1.5.1
#
# Model Details
#     Loading model - workspace/Task/gluon_resnet18_v1_train_all_layers/output/models/final-symbol.json
#     Model loaded!
#
# Experiment Details
#     Project: Task
#     Experiment: gluon_resnet18_v1_train_all_layers
#     Dir: /home/ubuntu/workspace/Task/gluon_resnet18_v1_train_all_layers/

# %% [markdown]
# ## Infer on some samples

# %%
img_name = "workspace/test/2.jpg"
predictions = gtf.Infer(img_name=img_name);
from IPython.display import Image
Image(filename=img_name, height=300, width=300)
# Out:
# Prediction
#     Image name:         workspace/test/2.jpg
#     Predicted class:      Interior
#     Predicted score:      0.9102534055709839

# %%
img_name = "workspace/test/3.jpg"
predictions = gtf.Infer(img_name=img_name);
from IPython.display import Image
Image(filename=img_name, height=300, width=300)
# Out:
# Prediction
#     Image name:         workspace/test/3.jpg
#     Predicted class:      kitchen
#     Predicted score:      0.8861647248268127

# %%
img_name = "workspace/test/4.jpg"
predictions = gtf.Infer(img_name=img_name);
from IPython.display import Image
Image(filename=img_name, height=300, width=300)
# Out:
# Prediction
#     Image name:         workspace/test/4.jpg
#     Predicted class:      living_room
#     Predicted score:      0.9992039799690247

# %%
img_name = "workspace/test/9.jpg"
predictions = gtf.Infer(img_name=img_name);
from IPython.display import Image
Image(filename=img_name, height=300, width=300)
# Out:
# Prediction
#     Image name:         workspace/test/9.jpg
#     Predicted class:      Exterior
#     Predicted score:      0.9892680644989014

# %%
img_name = "workspace/test/6.jpg"
predictions = gtf.Infer(img_name=img_name);
from IPython.display import Image
Image(filename=img_name, height=300, width=300)
# Out:
# Prediction
#     Image name:         workspace/test/6.jpg
#     Predicted class:      bedroom
#     Predicted score:      0.9997549057006836

# %%
img_name = "workspace/test/8.jpg"
predictions = gtf.Infer(img_name=img_name);
from IPython.display import Image
Image(filename=img_name, height=300, width=300)
# Out:
# Prediction
#     Image name:         workspace/test/8.jpg
#     Predicted class:      bathroom
#     Predicted score:      0.9998817443847656

# %%
img_name = "workspace/test/11.jpg"
predictions = gtf.Infer(img_name=img_name);
from IPython.display import Image
Image(filename=img_name, height=300, width=300)
# Out:
# Prediction
#     Image name:         workspace/test/11.jpg
#     Predicted class:      kitchen
#     Predicted score:      0.998856246471405

# %% [markdown]
# ---

# %% [markdown]
# # Training custom classifier from scratch

# %% [markdown]
# # What is resnet
#
# ## Readings on resnet
#
#   1) Points from https://towardsdatascience.com/an-overview-of-resnet-and-its-variants-5281e2f56035
#     - The core idea of ResNet is introducing a so-called “identity shortcut connection” that skips one or more layers
#     - The deeper model should not produce a training error higher than its shallower counterparts.
#     - solves the problem of vanishing gradiens as network depth increased - https://medium.com/@anishsingh20/the-vanishing-gradient-problem-48ae7f501257
#
#
#
#   2) Points from https://medium.com/@14prakash/understanding-and-implementing-architectures-of-resnet-and-resnext-for-state-of-the-art-image-cf51669e1624
#     - Won 1st place in the ILSVRC 2015 classification competition with top-5 error rate of 3.57% (An ensemble model)
#     - Efficiently trained networks with 100 layers and 1000 layers also.
#     - Replacing VGG-16 layers in Faster R-CNN with ResNet-101. They observed a relative improvements of 28%
#
#
#   3) Read more here
#     - https://arxiv.org/abs/1512.03385
#     - https://d2l.ai/chapter_convolutional-modern/resnet.html
#     - https://cv-tricks.com/keras/understand-implement-resnets/
#     - https://mc.ai/resnet-architecture-explained/

# %% [markdown]
# # Upcoming contents
#
# ## 1. Load the Dataset
#
# ## 2. Importing mxnet-gluon backend
#
# ## 3. Gluon resnet18_v1
#
# ## 4. Gluon resnet18_v1(training all layers)
#
# ## 5. Gluon resnet18_v2
#
# ## 6. Gluon resnet34_v1
#
# ## 7. Comparing all the models.

# %% [markdown]
# <a id='1'></a>
# # Loading the Dataset
#
# - Credits: https://omidpoursaeed.github.io/publication/vision-based-real-estate-price-estimation/

# %%
! wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=0BxDIywue_VABY1dRcFVvZ3BodnM' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=0BxDIywue_VABY1dRcFVvZ3BodnM" -O dataset.zip && rm -rf /tmp/cookies.txt

# %%
! unzip -qq dataset.zip

# %% [markdown]
# ---

# %% [markdown]
# <a id='2'></a>
# # Importing mxnet-gluon backend

# %%
#Using mxnet-gluon backend 

# When installed using pip
from monk.gluon_prototype import prototype


# When installed manually (Uncomment the following)
#import os
#import sys
#sys.path.append("monk_v1/");
#sys.path.append("monk_v1/monk/");
#from monk.gluon_prototype import prototype

# %% [markdown]
# # Train experiment with resnet-18 v1 architecture and validate

# %%
# Load experiment
monk_gln = prototype(verbose=1);
monk_gln.Prototype("Task", "gluon_resnet18_v1");

# Insert data and set params in default mode
monk_gln.Default(dataset_path="Train", 
            model_name="resnet18_v1", 
            freeze_base_network=True,
            num_epochs=10);

# %%
#Start Training
monk_gln.Train();

#Read the training summary generated once you run the cell and training is completed

# %%
# Load for test
monk_eval=prototype(verbose=1)
monk_eval.Prototype("Task", "gluon_resnet18_v1", eval_infer=True);

# %%
img_name = 'Train/bedroom/00004988.jpg'
pred = monk_eval.Infer(img_name=img_name);
from IPython.display import Image
Image(filename=img_name)
# Out:
# Prediction
#     Image name:         Train/bedroom/00004988.jpg
#     Predicted class:      bedroom
#     Predicted score:      0.9890945553779602

# %%
img_name = 'Train/Exterior/00004988.jpg'
pred = monk_eval.Infer(img_name=img_name);
from IPython.display import Image
Image(filename=img_name)
# Out:
# Prediction
#     Image name:         Train/Exterior/00004988.jpg
#     Predicted class:      Exterior
#     Predicted score:      0.999543309211731

# %% [markdown]
# ---

# %% [markdown]
# # Train experiment with resnet-18 v1 (training all layers) architecture and validate

# %%
# Load experiment
monk_gln = prototype(verbose=1);
monk_gln.Prototype("Task", "gluon_resnet18_v1_train_all_layers");

# Insert data and set params in default mode
monk_gln.Default(dataset_path="Train", 
            model_name="resnet18_v1", 
            freeze_base_network=False,
            num_epochs=10);

# %%
#Start Training
monk_gln.Train();

# %%
# Load for test
monk_eval=prototype(verbose=1)
monk_eval.Prototype("Task", "gluon_resnet18_v1_train_all_layers", eval_infer=True);

# %%
img_name = 'Train/bedroom/00004988.jpg'
pred = monk_eval.Infer(img_name=img_name);
from IPython.display import Image
Image(filename=img_name)
# Out:
# Prediction
#     Image name:         Train/bedroom/00004988.jpg
#     Predicted class:      bedroom
#     Predicted score:      0.8007224202156067

# %%
img_name = 'Train/Exterior/00004988.jpg'
pred = monk_eval.Infer(img_name=img_name);
from IPython.display import Image
Image(filename=img_name)
# Out:
# Prediction
#     Image name:         Train/Exterior/00004988.jpg
#     Predicted class:      Exterior
#     Predicted score:      0.999998152256012

# %% [markdown]
# <a id='4'></a>
# # Train experiment with resnet-18 v2 architecture and validate

# %%
# Load experiment
monk_gln = prototype(verbose=1);
monk_gln.Prototype("Task", "gluon-resnet18_v2");

# Insert data and set params in default mode
monk_gln.Default(dataset_path="Train", 
            model_name="resnet18_v2", 
            freeze_base_network=True,
            num_epochs=10);

# %%
#Start Training
monk_gln.Train()

# %%
# Load for test
monk_eval=prototype(verbose=1)
monk_eval.Prototype("Task", "gluon-resnet18_v2", eval_infer=True);

# %%
img_name = 'Train/bedroom/00004988.jpg'
pred = monk_eval.Infer(img_name=img_name);
from IPython.display import Image
Image(filename=img_name)
# Out:
# Prediction
#     Image name:         Train/bedroom/00004988.jpg
#     Predicted class:      bedroom
#     Predicted score:      0.9995241761207581

# %%
img_name = 'Train/Exterior/00004988.jpg'
pred = monk_eval.Infer(img_name=img_name);
from IPython.display import Image
Image(filename=img_name)
# Out:
# Prediction
#     Image name:         Train/Exterior/00004988.jpg
#     Predicted class:      Exterior
#     Predicted score:      0.9961346387863159

# %% [markdown]
# # Train experiment with resnet-34 v1 architecture and validate

# %%
# Load experiment
monk_gln = prototype(verbose=1);
monk_gln.Prototype("Task", "gluon-resnet34_v1");


# Insert data and set params in default mode
monk_gln.Default(dataset_path="Train", 
            model_name="resnet34_v1", 
            freeze_base_network=True,
            num_epochs=10);

# %%
#Start Training

monk_gln.Train()

# %%
# Load for test

monk_eval=prototype(verbose=1)
monk_eval.Prototype("Task", "gluon-resnet34_v1", eval_infer=True);

# %%
img_name = 'Train/bedroom/00004988.jpg'
pred = monk_eval.Infer(img_name=img_name);
from IPython.display import Image
Image(filename=img_name)
# Out:
# Prediction
#     Image name:         Train/bedroom/00004988.jpg
#     Predicted class:      bedroom
#     Predicted score:      0.8831295967102051

# %%
img_name = 'Train/Exterior/00004988.jpg'
pred = monk_eval.Infer(img_name=img_name);
from IPython.display import Image
Image(filename=img_name)
# Out:
# Prediction
#     Image name:         Train/Exterior/00004988.jpg
#     Predicted class:      Exterior
#     Predicted score:      0.9986181855201721

# %% [markdown]
# <a id='6'></a>
# # Comparing all the experiments.
# Using comparison class of Monk library.

# %%
# Invoke the comparison class
from monk.compare_prototype import compare

# %% [markdown]
# ### Creating and managing comparison experiments
#         - Provide project name

# %%
gtf = compare(verbose=1);
gtf.Comparison("Comparison-1");

# %% [markdown]
# ### This creates files and directories as per the following structure
#
#     workspace
#         |
#         |--------comparison
#                         |
#                         |
#                         |-----Compare-effect-of-network-depth
#                                     |
#                                     |------stats_best_val_acc.png
#                                     |------stats_max_gpu_usage.png
#                                     |------stats_training_time.png
#                                     |------train_accuracy.png
#                                     |------train_loss.png
#                                     |------val_accuracy.png
#                                     |------val_loss.png
#
#                         |
#                         |-----comparison.csv (Contains necessary details of all experiments)

# %% [markdown]
# ### Adding experiment to the comparison object.
#         - First argument - Project name
#         - Second argument - Experiment name

# %%
gtf.Add_Experiment("Task", "gluon_resnet18_v1");
gtf.Add_Experiment("Task", "gluon_resnet18_v1_train_all_layers");
gtf.Add_Experiment("Task", "gluon-resnet18_v2");
gtf.Add_Experiment("Task", "gluon-resnet34_v1");

# %% [markdown]
# ### Run analysis.

# %%
gtf.Generate_Statistics();

# %% [markdown]
# ## Visualize and study comparison metrics

# %% [markdown]
# ### Training Accuracy Curves

# %%
from IPython.display import Image
Image(filename="workspace/comparison/Comparison-1/train_accuracy.png")

# %% [markdown]
# ### Training Loss Curves

# %%
Image(filename="workspace/comparison/Comparison-1/train_loss.png")

# %% [markdown]
# ### Validation Accuracy Curves

# %%
Image(filename="workspace/comparison/Comparison-1/val_accuracy.png")

# %% [markdown]
# ### Validation Loss Curves

# %%
Image(filename="workspace/comparison/Comparison-1/val_loss.png")

# %% [markdown]
# ### Training time taken

# %%
Image(filename="workspace/comparison/Comparison-1/stats_training_time.png")

# %% [markdown]
# ### Max GPU usage

# %%
Image(filename="workspace/comparison/Comparison-1/stats_max_gpu_usage.png")

# %% [markdown]
# ### Best validation accuracy.

# %%
Image(filename="workspace/comparison/Comparison-1/stats_best_val_acc.png")

# %% [markdown]
# <a href="https://colab.research.google.com/github/Tessellate-Imaging/monk_v1/blob/master/study_roadmaps/4_image_classification_zoo/Classifier%20-%20Dog%20breed%20type.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Table of contents
#
#
# ## Install Monk
#
#
# ## Using pretrained model for classifying butterfly specie type in images
#
#
# ## Training a classifier from scratch (using default mode)

# %% [markdown]
# <a id='0'></a>
# # Install Monk

# %% [markdown]
# ## Using pip (Recommended)
#
#   - colab (gpu)
#       - All bakcends: `pip install -U monk-colab`
#
#
#   - kaggle (gpu)
#       - All backends: `pip install -U monk-kaggle`
#
#
#   - cuda 10.2
#       - All backends: `pip install -U monk-cuda102`
#       - Gluon bakcned: `pip install -U monk-gluon-cuda102`
# 	  - Pytorch backend: `pip install -U monk-pytorch-cuda102`
#       - Keras backend: `pip install -U monk-keras-cuda102`
#
#
#   - cuda 10.1
#       - All backend: `pip install -U monk-cuda101`
# 	  - Gluon bakcned: `pip install -U monk-gluon-cuda101`
# 	  - Pytorch backend: `pip install -U monk-pytorch-cuda101`
# 	  - Keras backend: `pip install -U monk-keras-cuda101`
#
#
#   - cuda 10.0
#       - All backend: `pip install -U monk-cuda100`
# 	  - Gluon bakcned: `pip install -U monk-gluon-cuda100`
# 	  - Pytorch backend: `pip install -U monk-pytorch-cuda100`
# 	  - Keras backend: `pip install -U monk-keras-cuda100`
#
#
#   - cuda 9.2
#       - All backend: `pip install -U monk-cuda92`
# 	  - Gluon bakcned: `pip install -U monk-gluon-cuda92`
# 	  - Pytorch backend: `pip install -U monk-pytorch-cuda92`
# 	  - Keras backend: `pip install -U monk-keras-cuda92`
#
#
#   - cuda 9.0
#       - All backend: `pip install -U monk-cuda90`
# 	  - Gluon bakcned: `pip install -U monk-gluon-cuda90`
# 	  - Pytorch backend: `pip install -U monk-pytorch-cuda90`
# 	  - Keras backend: `pip install -U monk-keras-cuda90`
#
#
#   - cpu
#       - All backend: `pip install -U monk-cpu`
# 	  - Gluon bakcned: `pip install -U monk-gluon-cpu`
# 	  - Pytorch backend: `pip install -U monk-pytorch-cpu`
# 	  - Keras backend: `pip install -U monk-keras-cpu`

# %% [markdown]
# ## Install Monk Manually (Not recommended)
#
# ### Step 1: Clone the library
#  - git clone https://github.com/Tessellate-Imaging/monk_v1.git
#
#
#
#
# ### Step 2: Install requirements
#  - Linux
#      - Cuda 9.0
#          - `cd monk_v1/installation/Linux && pip install -r requirements_cu90.txt`
#      - Cuda 9.2
#          - `cd monk_v1/installation/Linux && pip install -r requirements_cu92.txt`
#      - Cuda 10.0
#          - `cd monk_v1/installation/Linux && pip install -r requirements_cu100.txt`
#      - Cuda 10.1
#          - `cd monk_v1/installation/Linux && pip install -r requirements_cu101.txt`
#      - Cuda 10.2
#          - `cd monk_v1/installation/Linux && pip install -r requirements_cu102.txt`
#      - CPU (Non gpu system)
#          - `cd monk_v1/installation/Linux && pip install -r requirements_cpu.txt`
#
#
#   - Windows
#      - Cuda 9.0 (Experimental support)
#          - `cd monk_v1/installation/Windows && pip install -r requirements_cu90.txt`
#      - Cuda 9.2 (Experimental support)
#          - `cd monk_v1/installation/Windows && pip install -r requirements_cu92.txt`
#      - Cuda 10.0 (Experimental support)
#          - `cd monk_v1/installation/Windows && pip install -r requirements_cu100.txt`
#      - Cuda 10.1 (Experimental support)
#          - `cd monk_v1/installation/Windows && pip install -r requirements_cu101.txt`
#      - Cuda 10.2 (Experimental support)
#          - `cd monk_v1/installation/Windows && pip install -r requirements_cu102.txt`
#      - CPU (Non gpu system)
#          - `cd monk_v1/installation/Windows && pip install -r requirements_cpu.txt`
#
#
#   - Mac
#      - CPU (Non gpu system)
#          - `cd monk_v1/installation/Mac && pip install -r requirements_cpu.txt`
#
#
#   - Misc
#       - Colab (GPU)
#           - `cd monk_v1/installation/Misc && pip install -r requirements_colab.txt`
#       - Kaggle (GPU)
#           - `cd monk_v1/installation/Misc && pip install -r requirements_kaggle.txt`
#
#
#
# ### Step 3: Add to system path (Required for every terminal or kernel run)
#  - `import sys`
#  - `sys.path.append("monk_v1/");`

# %% [markdown]
# # Used trained classifier for demo

# %%
#Using mxnet-gluon backend 

# When installed using pip
from monk.gluon_prototype import prototype


# When installed manually (Uncomment the following)
#import os
#import sys
#sys.path.append("monk_v1/");
#sys.path.append("monk_v1/monk/");
#from monk.gluon_prototype import prototype

# %%
# Download trained weights

# %%
! wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1V2EKR2W9MuiKMES4YahP1biYd_jzo1OX' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1V2EKR2W9MuiKMES4YahP1biYd_jzo1OX" -O cls_butterfly_trained.zip && rm -rf /tmp/cookies.txt

# %%
! unzip -qq cls_butterfly_trained.zip

# %%
ls workspace/Project-ButterFly
# Out:
# Gluon-Densenet121/  Gluon-Densenet169/
# Gluon-Densenet161/  Gluon-Sample-Experiment/

# %%
# Load project in inference mode

gtf = prototype(verbose=1);
gtf.Prototype("Project-ButterFly", "Gluon-Densenet169", eval_infer=True);

#Other trained models - uncomment 
#gtf.Prototype("Project-ButterFly", "Gluon-Densenet161", eval_infer=True);
#gtf.Prototype("Project-ButterFly", "Gluon-Densenet121", eval_infer=True);
# Out:
# Mxnet Version: 1.5.1
#
# Model Details
#     Loading model - workspace/Project-ButterFly/Gluon-Densenet169/output/models/final-symbol.json
#     Model loaded!
#
# Experiment Details
#     Project: Project-ButterFly
#     Experiment: Gluon-Densenet169
#     Dir: /home/ubuntu/Desktop/butterfly/workspace/Project-ButterFly/Gluon-Densenet169/

# %%
# Infer

# %%
img_name = "workspace/test/1.jpg"
predictions = gtf.Infer(img_name=img_name);
from IPython.display import Image
Image(filename=img_name)
# Out:
# Prediction
#     Image name:         workspace/test/1.jpg
#     Predicted class:      016.Papilio_alcmenor
#     Predicted score:      0.9999847412109375

# %%
img_name = "workspace/test/2.jpg"
predictions = gtf.Infer(img_name=img_name);
from IPython.display import Image
Image(filename=img_name)
# Out:
# Prediction
#     Image name:         workspace/test/2.jpg
#     Predicted class:      180.Ampittia_virgata
#     Predicted score:      0.9997749328613281

# %%
img_name = "workspace/test/3.jpg"
predictions = gtf.Infer(img_name=img_name);
from IPython.display import Image
Image(filename=img_name)
# Out:
# Prediction
#     Image name:         workspace/test/3.jpg
#     Predicted class:      199.Hasora_badra
#     Predicted score:      0.986749529838562

# %%
img_name = "workspace/test/4.jpg"
predictions = gtf.Infer(img_name=img_name);
from IPython.display import Image
Image(filename=img_name)
# Out:
# Prediction
#     Image name:         workspace/test/4.jpg
#     Predicted class:      157.Abisara_echerius
#     Predicted score:      0.9995423555374146

# %%
img_name = "workspace/test/5.jpg"
predictions = gtf.Infer(img_name=img_name);
from IPython.display import Image
Image(filename=img_name)
# Out:
# Prediction
#     Image name:         workspace/test/5.jpg
#     Predicted class:      151.Polygonia_caureum
#     Predicted score:      0.9999618530273438

# %%
img_name = "workspace/test/6.jpg"
predictions = gtf.Infer(img_name=img_name);
from IPython.display import Image
Image(filename=img_name)
# Out:
# Prediction
#     Image name:         workspace/test/6.jpg
#     Predicted class:      198.Hasora_anura
#     Predicted score:      0.9994127750396729

# %%
img_name = "workspace/test/7.jpg"
predictions = gtf.Infer(img_name=img_name);
from IPython.display import Image
Image(filename=img_name)
# Out:
# Prediction
#     Image name:         workspace/test/7.jpg
#     Predicted class:      076.Danaus_genutia
#     Predicted score:      0.9999247193336487

# %%
img_name = "workspace/test/8.jpg"
predictions = gtf.Infer(img_name=img_name);
from IPython.display import Image
Image(filename=img_name)
# Out:
# Prediction
#     Image name:         workspace/test/8.jpg
#     Predicted class:      137.Acraea_terpsicore
#     Predicted score:      0.9998388290405273

# %% [markdown]
# # Training custom classifier from scratch

# %% [markdown]
# ## Dataset
#     - Credits: https://www.dropbox.com/sh/3p4x1oc5efknd69/AABwnyoH2EKi6H9Emcyd0pXCa?dl=0

# %% [markdown]
# ## Download

# %%
! wget https://www.dropbox.com/sh/3p4x1oc5efknd69/AABRyj0-ORMslo1vpRYwL3r5a/images_small.zip?dl=0

# %%
! mv images_small.zip?dl=0 images_small.zip

# %%
! unzip -qq images_small.zip

# %%
ls images_small
# Out:
# 001.Atrophaneura_horishanus/   101.Penthema_darlisa/
# 002.Atrophaneura_varuna/       102.Penthema_formosanum/
# 003.Byasa_alcinous/            103.Ypthima_baldus/
# 004.Byasa_dasarada/            104.Ypthima_praenubila/
# 005.Byasa_polyeuctes/          105.Aemona_amathusia/
# 006.Graphium_agamemnon/        106.Faunis_eumeus/
# 007.Graphium_cloanthus/        107.Stichophthalma_howqua/
# 008.Graphium_sarpedon/         108.Apatura_ilia/
# 009.Iphiclides_podalirius/     109.Apatura_iris/
# 010.Lamproptera_curius/        110.Chitoria_ulupi/
# 011.Lamproptera_meges/         111.Hestina_assimilis/
# 012.Losaria_coon/              112.Rohana_parisatis/
# 013.Meandrusa_payeni/          113.Sasakia_charonda/
# 014.Meandrusa_sciron/          114.Sephisa_chandra/
# 015.Pachliopta_aristolochiae/  115.Timelaea_albescens/
# 016.Papilio_alcmenor/          116.Ariadne_ariadne/
# 017.Papilio_arcturus/          117.Ariadne_merione/
# 018.Papilio_bianor/            118.Euthalia_niepelti/
# ...

# %% [markdown]
# ## Training

# %%
# Using mxnet-gluon backend 
from monk.gluon_prototype import prototype

# For pytorch backend
#from monk.pytorch_prototype import prototype

# For Keras backend
#from monk.keras_prototype import prototype

# %%
# Create Project and Experiment

gtf = prototype(verbose=1);
gtf.Prototype("Project-ButterFly", "Gluon-Sample-Experiment");
# Out:
# Mxnet Version: 1.5.1
#
# Experiment Details
#     Project: Project-ButterFly
#     Experiment: Gluon-Sample-Experiment
#     Dir: /home/ubuntu/Desktop/butterfly/workspace/Project-ButterFly/Gluon-Sample-Experiment/

# %%
gtf.List_Models()
# Out:
# Models List:
#     1. alexnet
#     2. darknet53
#     3. densenet121
#     4. densenet161
#     5. densenet169
#     6. densenet201
#     7. inceptionv3
#     8. mobilenet1.0
#     9. mobilenet0.75
#     10. mobilenet0.25
#     11. mobilenet0.5
#     12. resnet18_v1
#     13. resnet34_v1
#     14. resnet50_v1
#     15. resnet101_v1
#     16. resnet152_v1
#     17. resnext50_32x4d
#     18. resnext101_32x4d
#     19. resnext101_64x4d_v1
#     20. se_resnext50_32x4d
#     21. se_resnext101_32x4d
#     22. se_resnext101_64x4d
#     23. senet_154
#     24. vgg11
#     25. vgg13
#     26. vgg16
#     27. vgg19
#     28. vgg11_bn
#     29. vgg13_bn
#     30. vgg16_bn
#     31. vgg19_bn
#     32. resnet18_v2
#     33. resnet34_v2
#     34. resnet50_v2
#     35. resnet101_v2
#     36. resnet152_v2
#     37. mobilenetv2_1.0
#     38. mobilenetv2_0.75
#     39. mobilenetv2_0.5
#     40. mobilenetv2_0.25
#     41. squeezenet1.0
#     42. squeezenet1.1
#     43. mobilenetv3_large
# ...

# %%
gtf.Default(dataset_path="images_small",
            model_name="densenet121", 
            freeze_base_network=False,
            num_epochs=2);
# Out:
# Dataset Details
#     Train path:     images_small
#     Val path:       None
#     CSV train path: None
#     CSV val path:   None
#     Label Type:     single
#
# Dataset Params
#     Input Size:   224
#     Batch Size:   4
#     Data Shuffle: True
#     Processors:   8
#     Train-val split:   0.7
#
# Pre-Composed Train Transforms
# [{'RandomHorizontalFlip': {'p': 0.8}}, {'Normalize': {'mean': [0.485, 0.456, 0.406], 'std': [0.229, 0.224, 0.225]}}]
#
# Pre-Composed Val Transforms
# [{'RandomHorizontalFlip': {'p': 0.8}}, {'Normalize': {'mean': [0.485, 0.456, 0.406], 'std': [0.229, 0.224, 0.225]}}]
#
# Dataset Numbers
#     Num train images: 17695
#     Num val images:   7584
#     Num classes:      200
#
# Model Params
#     Model name:           densenet121
#     Use Gpu:              True
#     Use pretrained:       True
#     Freeze base network:  False
#
# Model Details
#     Loading pretrained model
# ...
# 100%|██████████| 29622/29622 [00:01<00:00, 29026.12KB/s]
# ...

# %% [markdown]
# ### How to change hyper parameters and models
#   - Docs - https://github.com/Tessellate-Imaging/monk_v1#4
#   - Examples - https://github.com/Tessellate-Imaging/monk_v1/tree/master/study_roadmaps/1_getting_started_roadmap

# %%
# Update batch size
gtf.update_batch_size(16);
gtf.update_save_intermediate_models(False);

# Reload after updates
gtf.Reload();

# %%
#Start Training
gtf.Train();

#Read the training summary generated once you run the cell and training is completed
# Out:
# Training Start
#     Epoch 1/2
#     ----------
# ...

# %% [markdown]
# # Inference (Post training)

# %%
# Using mxnet-gluon backend
# When installed using pip
from monk.gluon_prototype import prototype

# %%
gtf = prototype(verbose=1);
gtf.Prototype("Project-ButterFly", "Gluon-Sample-Experiment", eval_infer=True);

# %%
img_name = "images_small/001.Atrophaneura_horishanus/025.jpg"
predictions = gtf.Infer(img_name=img_name);
from IPython.display import Image
Image(filename=img_name)

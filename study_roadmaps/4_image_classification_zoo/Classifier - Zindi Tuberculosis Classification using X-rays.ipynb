# %% [markdown]
# <a href="https://colab.research.google.com/github/Tessellate-Imaging/monk_v1/blob/master/study_roadmaps/4_image_classification_zoo/Classifier%20-%20Zindi%20Bill%20Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Table of contents
#
#
# ## Install Monk
#
#
# ## Using pretrained model for classifying tuberculosis in images
#
#
# ## Training a classifier from scratch (Default mode)

# %% [markdown]
# # Install Monk

# %% [markdown]
# ## Using pip (Recommended)
#
#   - colab (gpu)
#       - All bakcends: `pip install -U monk-colab`
#
#
#   - kaggle (gpu)
#       - All backends: `pip install -U monk-kaggle`
#
#
#   - cuda 10.2
#       - All backends: `pip install -U monk-cuda102`
#       - Gluon bakcned: `pip install -U monk-gluon-cuda102`
# 	  - Pytorch backend: `pip install -U monk-pytorch-cuda102`
#       - Keras backend: `pip install -U monk-keras-cuda102`
#
#
#   - cuda 10.1
#       - All backend: `pip install -U monk-cuda101`
# 	  - Gluon bakcned: `pip install -U monk-gluon-cuda101`
# 	  - Pytorch backend: `pip install -U monk-pytorch-cuda101`
# 	  - Keras backend: `pip install -U monk-keras-cuda101`
#
#
#   - cuda 10.0
#       - All backend: `pip install -U monk-cuda100`
# 	  - Gluon bakcned: `pip install -U monk-gluon-cuda100`
# 	  - Pytorch backend: `pip install -U monk-pytorch-cuda100`
# 	  - Keras backend: `pip install -U monk-keras-cuda100`
#
#
#   - cuda 9.2
#       - All backend: `pip install -U monk-cuda92`
# 	  - Gluon bakcned: `pip install -U monk-gluon-cuda92`
# 	  - Pytorch backend: `pip install -U monk-pytorch-cuda92`
# 	  - Keras backend: `pip install -U monk-keras-cuda92`
#
#
#   - cuda 9.0
#       - All backend: `pip install -U monk-cuda90`
# 	  - Gluon bakcned: `pip install -U monk-gluon-cuda90`
# 	  - Pytorch backend: `pip install -U monk-pytorch-cuda90`
# 	  - Keras backend: `pip install -U monk-keras-cuda90`
#
#
#   - cpu
#       - All backend: `pip install -U monk-cpu`
# 	  - Gluon bakcned: `pip install -U monk-gluon-cpu`
# 	  - Pytorch backend: `pip install -U monk-pytorch-cpu`
# 	  - Keras backend: `pip install -U monk-keras-cpu`

# %% [markdown]
# ## Install Monk Manually (Not recommended)
#
# ### Step 1: Clone the library
#  - git clone https://github.com/Tessellate-Imaging/monk_v1.git
#
#
#
#
# ### Step 2: Install requirements
#  - Linux
#      - Cuda 9.0
#          - `cd monk_v1/installation/Linux && pip install -r requirements_cu90.txt`
#      - Cuda 9.2
#          - `cd monk_v1/installation/Linux && pip install -r requirements_cu92.txt`
#      - Cuda 10.0
#          - `cd monk_v1/installation/Linux && pip install -r requirements_cu100.txt`
#      - Cuda 10.1
#          - `cd monk_v1/installation/Linux && pip install -r requirements_cu101.txt`
#      - Cuda 10.2
#          - `cd monk_v1/installation/Linux && pip install -r requirements_cu102.txt`
#      - CPU (Non gpu system)
#          - `cd monk_v1/installation/Linux && pip install -r requirements_cpu.txt`
#
#
#   - Windows
#      - Cuda 9.0 (Experimental support)
#          - `cd monk_v1/installation/Windows && pip install -r requirements_cu90.txt`
#      - Cuda 9.2 (Experimental support)
#          - `cd monk_v1/installation/Windows && pip install -r requirements_cu92.txt`
#      - Cuda 10.0 (Experimental support)
#          - `cd monk_v1/installation/Windows && pip install -r requirements_cu100.txt`
#      - Cuda 10.1 (Experimental support)
#          - `cd monk_v1/installation/Windows && pip install -r requirements_cu101.txt`
#      - Cuda 10.2 (Experimental support)
#          - `cd monk_v1/installation/Windows && pip install -r requirements_cu102.txt`
#      - CPU (Non gpu system)
#          - `cd monk_v1/installation/Windows && pip install -r requirements_cpu.txt`
#
#
#   - Mac
#      - CPU (Non gpu system)
#          - `cd monk_v1/installation/Mac && pip install -r requirements_cpu.txt`
#
#
#   - Misc
#       - Colab (GPU)
#           - `cd monk_v1/installation/Misc && pip install -r requirements_colab.txt`
#       - Kaggle (GPU)
#           - `cd monk_v1/installation/Misc && pip install -r requirements_kaggle.txt`
#
#
#
# ### Step 3: Add to system path (Required for every terminal or kernel run)
#  - `import sys`
#  - `sys.path.append("monk_v1/");`

# %% [markdown]
# # Used trained classifier for demo

# %%
#Using mxnet-gluon backend 

# When installed using pip
from monk.gluon_prototype import prototype


# When installed manually (Uncomment the following)
#import os
#import sys
#sys.path.append("monk_v1/");
#sys.path.append("monk_v1/monk/");
#from monk.gluon_prototype import prototype

# %%
# Download trained weights

# %%
! wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1ZqOK8jZpYABGU9GhPwBdyzW_WBdZBQyO' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1ZqOK8jZpYABGU9GhPwBdyzW_WBdZBQyO" -O cls_tb_trained.zip && rm -rf /tmp/cookies.txt

# %%
! unzip -qq cls_tb_trained.zip

# %%
ls workspace/Project-TB
# Out:
# Gluon-Resnet101/  Gluon-Resnet50/   sample-experiment-1/
# Gluon-Resnet152/  Gluon-resnet152/

# %%
# Load project in inference mode

gtf = prototype(verbose=1);
gtf.Prototype("Project-TB", "Gluon-Resnet152", eval_infer=True);

#Other trained models - uncomment 
#gtf.Prototype("Project-TB", "Gluon-Resnet101", eval_infer=True);
#gtf.Prototype("Project-TB", "Gluon-Resnet50", eval_infer=True);
# Out:
# Mxnet Version: 1.5.1
#
# Model Details
#     Loading model - workspace/Project-TB/Gluon-Resnet152/output/models/final-symbol.json
#     Model loaded!
#
# Experiment Details
#     Project: Project-TB
#     Experiment: Gluon-Resnet152
#     Dir: /home/ubuntu/Desktop/tb/workspace/Project-TB/Gluon-Resnet152/

# %%
class_dict = {
    "0": "Normal Scan",
    "1": "Presence of Tuberculosis"
}

# %%
# Infer

# %%
img_name = "workspace/test/1.png"
predictions = gtf.Infer(img_name=img_name);
print("Analysis: {}".format(class_dict[predictions["predicted_class"]]))
from IPython.display import Image
Image(filename=img_name, width=300)
# Out:
# Prediction
#     Image name:         workspace/test/1.png
#     Predicted class:      1
#     Predicted score:      0.9874663352966309
#
# Analysis: Presence of Tuberculosis

# %%
img_name = "workspace/test/2.png"
predictions = gtf.Infer(img_name=img_name);
print("Analysis: {}".format(class_dict[predictions["predicted_class"]]))
from IPython.display import Image
Image(filename=img_name, width=300)
# Out:
# Prediction
#     Image name:         workspace/test/2.png
#     Predicted class:      0
#     Predicted score:      0.9870560765266418
#
# Analysis: Normal Scan

# %%
img_name = "workspace/test/3.png"
predictions = gtf.Infer(img_name=img_name);
print("Analysis: {}".format(class_dict[predictions["predicted_class"]]))
from IPython.display import Image
Image(filename=img_name, width=300)
# Out:
# Prediction
#     Image name:         workspace/test/3.png
#     Predicted class:      1
#     Predicted score:      0.9969048500061035
#
# Analysis: Presence of Tuberculosis

# %%
img_name = "workspace/test/4.png"
predictions = gtf.Infer(img_name=img_name);
print("Analysis: {}".format(class_dict[predictions["predicted_class"]]))
from IPython.display import Image
Image(filename=img_name, width=300)
# Out:
# Prediction
#     Image name:         workspace/test/4.png
#     Predicted class:      0
#     Predicted score:      0.6280131936073303
#
# Analysis: Normal Scan

# %% [markdown]
# ## Run on images for competition sumission

# %%
# When installed using pip
from monk.gluon_prototype import prototype

# %%
# Load project in inference mode

gtf = prototype(verbose=0);
gtf.Prototype("Project-TB", "Gluon-Resnet152", eval_infer=True);

# %%
import pandas as pd
df = pd.read_csv("SampleSubmission.csv")

# %%
from tqdm import tqdm
combined = [];
for i in tqdm(range(len(df))):
    img_name ="test_small/" + df["ID"][i] + ".png";
    predictions = gtf.Infer(img_name=img_name);
    combined.append([df["ID"][i], predictions["predicted_class"]])
# Out:
# 100%|██████████| 82/82 [00:01<00:00, 45.94it/s]

# %%
import pandas as pd
df = pd.DataFrame(combined, columns = ['ID', 'LABEL'])

# %%
df.to_csv("submission_tb.csv", index=False)

# %% [markdown]
# # Train your own detector

# %% [markdown]
# ## Download dataset
#   - From : https://zindi.africa/competitions/runmila-ai-institute-minohealth-ai-labs-tuberculosis-classification-via-x-rays-challenge/data

# %%
! unzip -qq test_small.zip

# %%
! unzip -qq train_small.zip

# %% [markdown]
# ## Data conversion

# %%
import pandas as pd
df = pd.read_csv("Train.csv");

# %%
df.columns
# Out:
# Index(['filename', 'ID', 'LABEL'], dtype='object')

# %%
df.iloc[0]
# Out:
# filename    train/VTYNBFTO.png
# ID                    VTYNBFTO
# LABEL                        1
# Name: 0, dtype: object

# %%
from tqdm import tqdm
combined = [];
for i in tqdm(range(len(df))):
    img_name = str(df["ID"][i]) + ".png";
    label = str(df["LABEL"][i])
    combined.append([img_name, label]);
# Out:
# 100%|██████████| 718/718 [00:00<00:00, 62334.62it/s]

# %%
df = pd.DataFrame(combined, columns = ['Img_Name', 'Label'])

# %%
df.to_csv("train_labels_modified.csv", index=False)

# %% [markdown]
# # Training

# %%
#Using mxnet-gluon backend 

# When installed using pip
from monk.gluon_prototype import prototype


# When installed manually (Uncomment the following)
#import os
#import sys
#sys.path.append("monk_v1/");
#sys.path.append("monk_v1/monk/");
#from monk.gluon_prototype import prototype

# %%
gtf = prototype(verbose=1);
gtf.Prototype("Project-TB", "sample-experiment-1");
# Out:
# Mxnet Version: 1.5.1
#
# Experiment Details
#     Project: Project-TB
#     Experiment: sample-experiment-1
#     Dir: /home/ubuntu/Desktop/tb/workspace/Project-TB/sample-experiment-1/

# %%
gtf.List_Models()
# Out:
# Models List:
#     1. alexnet
#     2. darknet53
#     3. densenet121
#     4. densenet161
#     5. densenet169
#     6. densenet201
#     7. inceptionv3
#     8. mobilenet1.0
#     9. mobilenet0.75
#     10. mobilenet0.25
#     11. mobilenet0.5
#     12. resnet18_v1
#     13. resnet34_v1
#     14. resnet50_v1
#     15. resnet101_v1
#     16. resnet152_v1
#     17. resnext50_32x4d
#     18. resnext101_32x4d
#     19. resnext101_64x4d_v1
#     20. se_resnext50_32x4d
#     21. se_resnext101_32x4d
#     22. se_resnext101_64x4d
#     23. senet_154
#     24. vgg11
#     25. vgg13
#     26. vgg16
#     27. vgg19
#     28. vgg11_bn
#     29. vgg13_bn
#     30. vgg16_bn
#     31. vgg19_bn
#     32. resnet18_v2
#     33. resnet34_v2
#     34. resnet50_v2
#     35. resnet101_v2
#     36. resnet152_v2
#     37. mobilenetv2_1.0
#     38. mobilenetv2_0.75
#     39. mobilenetv2_0.5
#     40. mobilenetv2_0.25
#     41. squeezenet1.0
#     42. squeezenet1.1
#     43. mobilenetv3_large
# ...

# %%
gtf.Default(dataset_path="train_small",
            path_to_csv="train_labels_modified.csv",
            model_name="resnet50_v2", 
            freeze_base_network=False,
            num_epochs=5);
# Out:
# Dataset Details
#     Train path:     train_small
#     Val path:       None
#     CSV train path: train_labels_modified.csv
#     CSV val path:   None
#     Label Type:     single
#
# Dataset Params
#     Input Size:   224
#     Batch Size:   4
#     Data Shuffle: True
#     Processors:   8
#     Train-val split:   0.7
#     Delimiter:   ,
#
# Pre-Composed Train Transforms
# [{'RandomHorizontalFlip': {'p': 0.8}}, {'Normalize': {'mean': [0.485, 0.456, 0.406], 'std': [0.229, 0.224, 0.225]}}]
#
# Pre-Composed Val Transforms
# [{'RandomHorizontalFlip': {'p': 0.8}}, {'Normalize': {'mean': [0.485, 0.456, 0.406], 'std': [0.229, 0.224, 0.225]}}]
#
# Dataset Numbers
#     Num train images: 502
#     Num val images:   216
#     Num classes:      2
#
# Model Params
#     Model name:           resnet50_v2
#     Use Gpu:              True
#     Use pretrained:       True
#     Freeze base network:  False
#
# Model Details
#     Loading pretrained model
#     Model Loaded on device
# ...

# %%
gtf.update_batch_size(16);
gtf.update_save_intermediate_models(False);

#Important to reload post updates
gtf.Reload();
# Out:
# Update: Batch size - 16
#
# Update: Save Intermediate models - False
#
# Pre-Composed Train Transforms
# [{'RandomHorizontalFlip': {'p': 0.8}}, {'Normalize': {'mean': [0.485, 0.456, 0.406], 'std': [0.229, 0.224, 0.225]}}]
#
# Pre-Composed Val Transforms
# [{'RandomHorizontalFlip': {'p': 0.8}}, {'Normalize': {'mean': [0.485, 0.456, 0.406], 'std': [0.229, 0.224, 0.225]}}]
#
# Dataset Numbers
#     Num train images: 502
#     Num val images:   216
#     Num classes:      2
#
# Model Details
#     Loading pretrained model
#     Model Loaded on device
#         Model name:                           resnet50_v2
#         Num of potentially trainable layers:  105
#         Num of actual trainable layers:       104

# %%
gtf.Train();
# Out:
# Training Start
#     Epoch 1/5
#     ----------
# ...
#     curr_lr - 0.01
#     [Epoch 1] Train-acc: 0.741, Train-loss: 0.581 | Val-acc: 0.805556, Val-loss: 0.425, | time: 3.9 sec
#
#     Epoch 2/5
#     ----------
# ...
#     curr_lr - 0.0098
#     [Epoch 2] Train-acc: 0.815, Train-loss: 0.440 | Val-acc: 0.703704, Val-loss: 0.645, | time: 3.7 sec
#
#     Epoch 3/5
#     ----------
# ...
#     curr_lr - 0.009604
#     [Epoch 3] Train-acc: 0.867, Train-loss: 0.320 | Val-acc: 0.800926, Val-loss: 0.515, | time: 3.8 sec
#
#     Epoch 4/5
#     ----------
# ...
#     curr_lr - 0.009411919999999999
#     [Epoch 4] Train-acc: 0.922, Train-loss: 0.201 | Val-acc: 0.824074, Val-loss: 0.513, | time: 4.0 sec
#
#     Epoch 5/5
#     ----------
# ...
#     curr_lr - 0.009223681599999999
#     [Epoch 5] Train-acc: 0.948, Train-loss: 0.162 | Val-acc: 0.777778, Val-loss: 0.563, | time: 3.8 sec
#
#     Training completed in: 0m 15s
#     Best val Acc:          0.824074
#
# Training End
#
# Training Outputs
# ...

# %% [markdown]
# # Run on test images - for submission

# %%
# When installed using pip
from monk.gluon_prototype import prototype

# %%
gtf = prototype(verbose=0);
gtf.Prototype("Project-TB", "sample-experiment-1", eval_infer=True);

# %%
import pandas as pd
df = pd.read_csv("SampleSubmission.csv")
df.head()
# Out:
#          ID  LABEL
# 0  GTWSHFYQ      0
# 1  QTFSSMGD      0
# 2  TBLBHSYT      0
# 3  ZKETEOFG      0
# 4  GKTPBGZP      0

# %%
from tqdm import tqdm
combined = [];
for i in tqdm(range(len(df))):
    img_name ="test_small/" + df["ID"][i] + ".png";
    predictions = gtf.Infer(img_name=img_name);
    combined.append([df["ID"][i], predictions["predicted_class"]])
# Out:
# 100%|██████████| 82/82 [00:01<00:00, 67.39it/s]

# %%
combined[:5]
# Out:
# [['GTWSHFYQ', '0'],
#  ['QTFSSMGD', '0'],
#  ['TBLBHSYT', '1'],
#  ['ZKETEOFG', '0'],
#  ['GKTPBGZP', '0']]

# %%
import pandas as pd
df = pd.DataFrame(combined, columns = ['ID', 'LABEL'])

# %%
df.to_csv("submission_tb.csv", index=False)

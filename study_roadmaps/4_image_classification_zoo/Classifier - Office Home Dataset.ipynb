# %% [markdown]
# <a href="https://colab.research.google.com/github/Tessellate-Imaging/monk_v1/blob/master/study_roadmaps/4_image_classification_zoo/Classifier%20-%20Butterfly%20Specie%20Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Table of contents
#
#
# ## Install Monk
#
#
# ## Using pretrained model for classifying butterfly specie type in images
#
#
# ## Training a classifier from scratch (using default mode)

# %% [markdown]
# <a id='0'></a>
# # Install Monk

# %% [markdown]
# ## Using pip (Recommended)
#
#   - colab (gpu)
#       - All bakcends: `pip install -U monk-colab`
#
#
#   - kaggle (gpu)
#       - All backends: `pip install -U monk-kaggle`
#
#
#   - cuda 10.2
#       - All backends: `pip install -U monk-cuda102`
#       - Gluon bakcned: `pip install -U monk-gluon-cuda102`
# 	  - Pytorch backend: `pip install -U monk-pytorch-cuda102`
#       - Keras backend: `pip install -U monk-keras-cuda102`
#
#
#   - cuda 10.1
#       - All backend: `pip install -U monk-cuda101`
# 	  - Gluon bakcned: `pip install -U monk-gluon-cuda101`
# 	  - Pytorch backend: `pip install -U monk-pytorch-cuda101`
# 	  - Keras backend: `pip install -U monk-keras-cuda101`
#
#
#   - cuda 10.0
#       - All backend: `pip install -U monk-cuda100`
# 	  - Gluon bakcned: `pip install -U monk-gluon-cuda100`
# 	  - Pytorch backend: `pip install -U monk-pytorch-cuda100`
# 	  - Keras backend: `pip install -U monk-keras-cuda100`
#
#
#   - cuda 9.2
#       - All backend: `pip install -U monk-cuda92`
# 	  - Gluon bakcned: `pip install -U monk-gluon-cuda92`
# 	  - Pytorch backend: `pip install -U monk-pytorch-cuda92`
# 	  - Keras backend: `pip install -U monk-keras-cuda92`
#
#
#   - cuda 9.0
#       - All backend: `pip install -U monk-cuda90`
# 	  - Gluon bakcned: `pip install -U monk-gluon-cuda90`
# 	  - Pytorch backend: `pip install -U monk-pytorch-cuda90`
# 	  - Keras backend: `pip install -U monk-keras-cuda90`
#
#
#   - cpu
#       - All backend: `pip install -U monk-cpu`
# 	  - Gluon bakcned: `pip install -U monk-gluon-cpu`
# 	  - Pytorch backend: `pip install -U monk-pytorch-cpu`
# 	  - Keras backend: `pip install -U monk-keras-cpu`

# %% [markdown]
# ## Install Monk Manually (Not recommended)
#
# ### Step 1: Clone the library
#  - git clone https://github.com/Tessellate-Imaging/monk_v1.git
#
#
#
#
# ### Step 2: Install requirements
#  - Linux
#      - Cuda 9.0
#          - `cd monk_v1/installation/Linux && pip install -r requirements_cu90.txt`
#      - Cuda 9.2
#          - `cd monk_v1/installation/Linux && pip install -r requirements_cu92.txt`
#      - Cuda 10.0
#          - `cd monk_v1/installation/Linux && pip install -r requirements_cu100.txt`
#      - Cuda 10.1
#          - `cd monk_v1/installation/Linux && pip install -r requirements_cu101.txt`
#      - Cuda 10.2
#          - `cd monk_v1/installation/Linux && pip install -r requirements_cu102.txt`
#      - CPU (Non gpu system)
#          - `cd monk_v1/installation/Linux && pip install -r requirements_cpu.txt`
#
#
#   - Windows
#      - Cuda 9.0 (Experimental support)
#          - `cd monk_v1/installation/Windows && pip install -r requirements_cu90.txt`
#      - Cuda 9.2 (Experimental support)
#          - `cd monk_v1/installation/Windows && pip install -r requirements_cu92.txt`
#      - Cuda 10.0 (Experimental support)
#          - `cd monk_v1/installation/Windows && pip install -r requirements_cu100.txt`
#      - Cuda 10.1 (Experimental support)
#          - `cd monk_v1/installation/Windows && pip install -r requirements_cu101.txt`
#      - Cuda 10.2 (Experimental support)
#          - `cd monk_v1/installation/Windows && pip install -r requirements_cu102.txt`
#      - CPU (Non gpu system)
#          - `cd monk_v1/installation/Windows && pip install -r requirements_cpu.txt`
#
#
#   - Mac
#      - CPU (Non gpu system)
#          - `cd monk_v1/installation/Mac && pip install -r requirements_cpu.txt`
#
#
#   - Misc
#       - Colab (GPU)
#           - `cd monk_v1/installation/Misc && pip install -r requirements_colab.txt`
#       - Kaggle (GPU)
#           - `cd monk_v1/installation/Misc && pip install -r requirements_kaggle.txt`
#
#
#
# ### Step 3: Add to system path (Required for every terminal or kernel run)
#  - `import sys`
#  - `sys.path.append("monk_v1/");`

# %% [markdown]
# # Used trained classifier for demo

# %%
#Using mxnet-gluon backend 

# When installed using pip
from monk.gluon_prototype import prototype


# When installed manually (Uncomment the following)
#import os
#import sys
#sys.path.append("monk_v1/");
#sys.path.append("monk_v1/monk/");
#from monk.gluon_prototype import prototype

# %%
# Download trained weights

# %%
! wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1obnrBPMMX1rUkskMz8S4PY6XnoUUKRvQ' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1obnrBPMMX1rUkskMz8S4PY6XnoUUKRvQ" -O cls_officehome_trained.zip && rm -rf /tmp/cookies.txt

# %%
! unzip -qq cls_officehome_trained.zip

# %%
ls workspace/Project-Office-Home
# Out:
# Gluon-vgg13_bn/  Gluon-vgg16_bn/  Gluon-vgg19_bn/

# %%
# Load project in inference mode

gtf = prototype(verbose=1);
gtf.Prototype("Project-Office-Home", "Gluon-vgg19_bn", eval_infer=True);

#Other trained models - uncomment 
#gtf.Prototype("Project-Office-Home", "Gluon-vgg16_bn", eval_infer=True);
#gtf.Prototype("Project-Office-Home", "Gluon-vgg13_bn", eval_infer=True);
# Out:
# Mxnet Version: 1.5.1
#
# Model Details
#     Loading model - workspace/Project-Office-Home/Gluon-vgg19_bn/output/models/final-symbol.json
#     Model loaded!
#
# Experiment Details
#     Project: Project-Office-Home
#     Experiment: Gluon-vgg19_bn
#     Dir: /home/ubuntu/Desktop/office_home/workspace/Project-Office-Home/Gluon-vgg19_bn/

# %%
! cp images/1060.jpg workspace/test/8.jpg

# %%
# Infer

# %%
img_name = "workspace/test/1.jpg"
predictions = gtf.Infer(img_name=img_name);
from IPython.display import Image
Image(filename=img_name)
# Out:
# Prediction
#     Image name:         workspace/test/1.jpg
#     Predicted class:      Real_World_Backpack
#     Predicted score:      0.5163754820823669

# %%
img_name = "workspace/test/2.jpg"
predictions = gtf.Infer(img_name=img_name);
from IPython.display import Image
Image(filename=img_name)
# Out:
# Prediction
#     Image name:         workspace/test/2.jpg
#     Predicted class:      Product_Helmet
#     Predicted score:      0.979249894618988

# %%
img_name = "workspace/test/3.jpg"
predictions = gtf.Infer(img_name=img_name);
from IPython.display import Image
Image(filename=img_name)
# Out:
# Prediction
#     Image name:         workspace/test/3.jpg
#     Predicted class:      Product_Calendar
#     Predicted score:      0.9983210563659668

# %%
img_name = "workspace/test/4.jpg"
predictions = gtf.Infer(img_name=img_name);
from IPython.display import Image
Image(filename=img_name)
# Out:
# Prediction
#     Image name:         workspace/test/4.jpg
#     Predicted class:      Real_World_Pen
#     Predicted score:      0.8404918313026428

# %%
img_name = "workspace/test/5.jpg"
predictions = gtf.Infer(img_name=img_name);
from IPython.display import Image
Image(filename=img_name)
# Out:
# Prediction
#     Image name:         workspace/test/5.jpg
#     Predicted class:      Product_Chair
#     Predicted score:      0.9658707976341248

# %%
img_name = "workspace/test/6.jpg"
predictions = gtf.Infer(img_name=img_name);
from IPython.display import Image
Image(filename=img_name)
# Out:
# Prediction
#     Image name:         workspace/test/6.jpg
#     Predicted class:      Product_TV
#     Predicted score:      0.9793741703033447

# %%
img_name = "workspace/test/7.jpg"
predictions = gtf.Infer(img_name=img_name);
from IPython.display import Image
Image(filename=img_name)
# Out:
# Prediction
#     Image name:         workspace/test/7.jpg
#     Predicted class:      Product_Printer
#     Predicted score:      0.9921498894691467

# %%
img_name = "workspace/test/8.jpg"
predictions = gtf.Infer(img_name=img_name);
from IPython.display import Image
Image(filename=img_name)
# Out:
# Prediction
#     Image name:         workspace/test/8.jpg
#     Predicted class:      Product_Calculator
#     Predicted score:      0.944355309009552

# %% [markdown]
# # Training custom classifier from scratch

# %% [markdown]
# ## Dataset
#     - Credits: http://hemanthdv.org/OfficeHome-Dataset/

# %% [markdown]
# ## Download

# %%
! wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=0B81rNlvomiwed0V1YUxQdC1uOTg' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=0B81rNlvomiwed0V1YUxQdC1uOTg" -O OfficeHomeDataset_10072016.zip && rm -rf /tmp/cookies.txt

# %%
! unzip -qq OfficeHomeDataset_10072016.zip

# %%
! mv OfficeHomeDataset_10072016/ImageInfo.csv .
! mv OfficeHomeDataset_10072016/imagelist.txt .
! mv OfficeHomeDataset_10072016/Real\ World OfficeHomeDataset_10072016/Real_World

# %%
! mkdir images

# %%
import os
from tqdm import tqdm
import pandas as pd

# %%
combined = [];
img_num = 0;
major_labels = os.listdir("OfficeHomeDataset_10072016");
for i in tqdm(range(len(major_labels))):
    minor_labels = os.listdir("OfficeHomeDataset_10072016/" + major_labels[i]);
    for j in tqdm(range(len(minor_labels))):
        img_list =  os.listdir("OfficeHomeDataset_10072016/" + major_labels[i] + "/" + minor_labels[j]);
        label = major_labels[i] + "_" + minor_labels[j];
        for k in range(len(img_list)):
            cmd = "cp OfficeHomeDataset_10072016/" + major_labels[i] + "/" + minor_labels[j] + "/" + img_list[k] + " images/" + str(img_num) + ".jpg";
            combined.append([str(img_num) + ".jpg", label]);
            os.system(cmd)
            img_num += 1;

# %%
df = pd.DataFrame(combined, columns = ['ID', 'LABEL'])  
df.to_csv("train_labels.csv", index=False);

# %% [markdown]
# ## Training

# %%
# Using mxnet-gluon backend 
from monk.gluon_prototype import prototype

# For pytorch backend
#from monk.pytorch_prototype import prototype

# For Keras backend
#from monk.keras_prototype import prototype

# %%
# Create Project and Experiment

gtf = prototype(verbose=1);
gtf.Prototype("Project-Office-Home", "Gluon-vgg13_bn");

# %%
gtf.List_Models()
# Out:
# Models List:
#     1. alexnet
#     2. darknet53
#     3. densenet121
#     4. densenet161
#     5. densenet169
#     6. densenet201
#     7. inceptionv3
#     8. mobilenet1.0
#     9. mobilenet0.75
#     10. mobilenet0.25
#     11. mobilenet0.5
#     12. resnet18_v1
#     13. resnet34_v1
#     14. resnet50_v1
#     15. resnet101_v1
#     16. resnet152_v1
#     17. resnext50_32x4d
#     18. resnext101_32x4d
#     19. resnext101_64x4d_v1
#     20. se_resnext50_32x4d
#     21. se_resnext101_32x4d
#     22. se_resnext101_64x4d
#     23. senet_154
#     24. vgg11
#     25. vgg13
#     26. vgg16
#     27. vgg19
#     28. vgg11_bn
#     29. vgg13_bn
#     30. vgg16_bn
#     31. vgg19_bn
#     32. resnet18_v2
#     33. resnet34_v2
#     34. resnet50_v2
#     35. resnet101_v2
#     36. resnet152_v2
#     37. mobilenetv2_1.0
#     38. mobilenetv2_0.75
#     39. mobilenetv2_0.5
#     40. mobilenetv2_0.25
#     41. squeezenet1.0
#     42. squeezenet1.1
#     43. mobilenetv3_large
# ...

# %%
gtf.Default(dataset_path="images",
            path_to_csv="train_labels.csv",
            model_name="vgg13_bn", 
            freeze_base_network=False,
            num_epochs=100);

# %% [markdown]
# ### How to change hyper parameters and models
#   - Docs - https://github.com/Tessellate-Imaging/monk_v1#4
#   - Examples - https://github.com/Tessellate-Imaging/monk_v1/tree/master/study_roadmaps/1_getting_started_roadmap

# %%
# Update batch size
gtf.update_batch_size(32);
gtf.update_save_intermediate_models(False);

# Reload after updates
gtf.Reload();

# %%
#Start Training
gtf.Train();

#Read the training summary generated once you run the cell and training is completed
# Out:
# Training Start
#     Epoch 1/2
#     ----------
# ...

# %% [markdown]
# # Inference (Post training)

# %%
# Using mxnet-gluon backend
# When installed using pip
from monk.gluon_prototype import prototype

# %%
gtf = prototype(verbose=1);
gtf.Prototype("Project-Office-Home", "Gluon-vgg13_bn", eval_infer=True);

# %%
img_name = "images/1.jpg"
predictions = gtf.Infer(img_name=img_name);
from IPython.display import Image
Image(filename=img_name)

# %% [markdown]
# <a href="https://colab.research.google.com/github/Tessellate-Imaging/monk_v1/blob/master/study_roadmaps/4_image_classification_zoo/Classifier%20-%20Swedish%20Leaf%20Type%20Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Table of contents
#
#
# ## Install Monk
#
#
# ## Using pretrained model for image understanding
#
#
# ## Training a classifier from scratch (using Monk's default mode)

# %% [markdown]
# <a id='0'></a>
# # Install Monk

# %% [markdown]
# ## Using pip (Recommended)
#
#   - colab (gpu)
#       - All bakcends: `pip install -U monk-colab`
#
#
#   - kaggle (gpu)
#       - All backends: `pip install -U monk-kaggle`
#
#
#   - cuda 10.2
#       - All backends: `pip install -U monk-cuda102`
#       - Gluon bakcned: `pip install -U monk-gluon-cuda102`
# 	  - Pytorch backend: `pip install -U monk-pytorch-cuda102`
#       - Keras backend: `pip install -U monk-keras-cuda102`
#
#
#   - cuda 10.1
#       - All backend: `pip install -U monk-cuda101`
# 	  - Gluon bakcned: `pip install -U monk-gluon-cuda101`
# 	  - Pytorch backend: `pip install -U monk-pytorch-cuda101`
# 	  - Keras backend: `pip install -U monk-keras-cuda101`
#
#
#   - cuda 10.0
#       - All backend: `pip install -U monk-cuda100`
# 	  - Gluon bakcned: `pip install -U monk-gluon-cuda100`
# 	  - Pytorch backend: `pip install -U monk-pytorch-cuda100`
# 	  - Keras backend: `pip install -U monk-keras-cuda100`
#
#
#   - cuda 9.2
#       - All backend: `pip install -U monk-cuda92`
# 	  - Gluon bakcned: `pip install -U monk-gluon-cuda92`
# 	  - Pytorch backend: `pip install -U monk-pytorch-cuda92`
# 	  - Keras backend: `pip install -U monk-keras-cuda92`
#
#
#   - cuda 9.0
#       - All backend: `pip install -U monk-cuda90`
# 	  - Gluon bakcned: `pip install -U monk-gluon-cuda90`
# 	  - Pytorch backend: `pip install -U monk-pytorch-cuda90`
# 	  - Keras backend: `pip install -U monk-keras-cuda90`
#
#
#   - cpu
#       - All backend: `pip install -U monk-cpu`
# 	  - Gluon bakcned: `pip install -U monk-gluon-cpu`
# 	  - Pytorch backend: `pip install -U monk-pytorch-cpu`
# 	  - Keras backend: `pip install -U monk-keras-cpu`

# %% [markdown]
# ## Install Monk Manually (Not recommended)
#
# ### Step 1: Clone the library
#  - git clone https://github.com/Tessellate-Imaging/monk_v1.git
#
#
#
#
# ### Step 2: Install requirements
#  - Linux
#      - Cuda 9.0
#          - `cd monk_v1/installation/Linux && pip install -r requirements_cu90.txt`
#      - Cuda 9.2
#          - `cd monk_v1/installation/Linux && pip install -r requirements_cu92.txt`
#      - Cuda 10.0
#          - `cd monk_v1/installation/Linux && pip install -r requirements_cu100.txt`
#      - Cuda 10.1
#          - `cd monk_v1/installation/Linux && pip install -r requirements_cu101.txt`
#      - Cuda 10.2
#          - `cd monk_v1/installation/Linux && pip install -r requirements_cu102.txt`
#      - CPU (Non gpu system)
#          - `cd monk_v1/installation/Linux && pip install -r requirements_cpu.txt`
#
#
#   - Windows
#      - Cuda 9.0 (Experimental support)
#          - `cd monk_v1/installation/Windows && pip install -r requirements_cu90.txt`
#      - Cuda 9.2 (Experimental support)
#          - `cd monk_v1/installation/Windows && pip install -r requirements_cu92.txt`
#      - Cuda 10.0 (Experimental support)
#          - `cd monk_v1/installation/Windows && pip install -r requirements_cu100.txt`
#      - Cuda 10.1 (Experimental support)
#          - `cd monk_v1/installation/Windows && pip install -r requirements_cu101.txt`
#      - Cuda 10.2 (Experimental support)
#          - `cd monk_v1/installation/Windows && pip install -r requirements_cu102.txt`
#      - CPU (Non gpu system)
#          - `cd monk_v1/installation/Windows && pip install -r requirements_cpu.txt`
#
#
#   - Mac
#      - CPU (Non gpu system)
#          - `cd monk_v1/installation/Mac && pip install -r requirements_cpu.txt`
#
#
#   - Misc
#       - Colab (GPU)
#           - `cd monk_v1/installation/Misc && pip install -r requirements_colab.txt`
#       - Kaggle (GPU)
#           - `cd monk_v1/installation/Misc && pip install -r requirements_kaggle.txt`
#
#
#
# ### Step 3: Add to system path (Required for every terminal or kernel run)
#  - `import sys`
#  - `sys.path.append("monk_v1/");`

# %% [markdown]
# # Used trained classifier for demo

# %%
#Using pytorch backend 

# When installed using pip
from monk.pytorch_prototype import prototype


# When installed manually (Uncomment the following)
#import os
#import sys
#sys.path.append("monk_v1/");
#sys.path.append("monk_v1/monk/");
#from monk.gluon_prototype import prototype

# %%
# Download trained weights

# %%
! wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1TvcbVYFdZ_RHl4KGziPaMezp_Hg3yhXT' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1TvcbVYFdZ_RHl4KGziPaMezp_Hg3yhXT" -O cls_image_understanding_trained.zip && rm -rf /tmp/cookies.txt

# %%
! unzip -qq cls_image_understanding_trained.zip

# %%
ls workspace/Project-Image-Understanding
# Out:
# Pytorch-Resnet101/  Pytorch-Resnet152/  Pytorch-Resnet50/

# %%
# Load project in inference mode

gtf = prototype(verbose=1);
gtf.Prototype("Project-Image-Understanding", "Pytorch-Resnet152", eval_infer=True);

#Other trained models - uncomment 
#gtf.Prototype("Project-Image-Understanding", "Pytorch-Resnet101", eval_infer=True);
#gtf.Prototype("Project-Image-Understanding", "Pytorch-Resnet50", eval_infer=True);
# Out:
# Pytorch Version: 1.4.0
#
# Model Details
#     Loading model - workspace/Project-Image-Understanding/Pytorch-Resnet152/output/models/final
#     Model loaded!
#
# Experiment Details
#     Project: Project-Image-Understanding
#     Experiment: Pytorch-Resnet152
#     Dir: /home/ubuntu/Desktop/microsoft/workspace/Project-Image-Understanding/Pytorch-Resnet152/

# %%
# Infer

# %%
img_name = "workspace/test/1.JPG"
predictions = gtf.Infer(img_name=img_name);
from IPython.display import Image
Image(filename=img_name)
# Out:
# Prediction
#     Image name:         workspace/test/1.JPG
#     Predicted class:      aeroplanes
#     Predicted score:      0.9999495148658752

# %%
img_name = "workspace/test/2.JPG"
predictions = gtf.Infer(img_name=img_name);
from IPython.display import Image
Image(filename=img_name)
# Out:
# Prediction
#     Image name:         workspace/test/2.JPG
#     Predicted class:      countryside
#     Predicted score:      0.999377429485321

# %%
img_name = "workspace/test/3.JPG"
predictions = gtf.Infer(img_name=img_name);
from IPython.display import Image
Image(filename=img_name)
# Out:
# Prediction
#     Image name:         workspace/test/3.JPG
#     Predicted class:      urban
#     Predicted score:      0.9951509237289429

# %%
img_name = "workspace/test/4.JPG"
predictions = gtf.Infer(img_name=img_name);
from IPython.display import Image
Image(filename=img_name)
# Out:
# Prediction
#     Image name:         workspace/test/4.JPG
#     Predicted class:      buildings
#     Predicted score:      0.9997997283935547

# %%
img_name = "workspace/test/5.JPG"
predictions = gtf.Infer(img_name=img_name);
from IPython.display import Image
Image(filename=img_name)
# Out:
# Prediction
#     Image name:         workspace/test/5.JPG
#     Predicted class:      cars
#     Predicted score:      0.9983838796615601

# %%
img_name = "workspace/test/6.JPG"
predictions = gtf.Infer(img_name=img_name);
from IPython.display import Image
Image(filename=img_name)
# Out:
# Prediction
#     Image name:         workspace/test/6.JPG
#     Predicted class:      office
#     Predicted score:      0.9980725646018982

# %%
img_name = "workspace/test/7.JPG"
predictions = gtf.Infer(img_name=img_name);
from IPython.display import Image
Image(filename=img_name)
# Out:
# Prediction
#     Image name:         workspace/test/7.JPG
#     Predicted class:      benches_and_chairs
#     Predicted score:      0.9994498491287231

# %%
img_name = "workspace/test/8.JPG"
predictions = gtf.Infer(img_name=img_name);
from IPython.display import Image
Image(filename=img_name)
# Out:
# Prediction
#     Image name:         workspace/test/8.JPG
#     Predicted class:      clouds
#     Predicted score:      0.9999513626098633

# %% [markdown]
# # Training custom classifier from scratch

# %% [markdown]
# ## Dataset
#     - Credits: https://www.microsoft.com/en-us/research/project/image-understanding/?from=http%3A%2F%2Fresearch.microsoft.com%2Fen-us%2Fprojects%2Fobjectclassrecognition%2Fdefault.aspx#!downloads

# %% [markdown]
# ## Download

# %%
! wget https://download.microsoft.com/download/5/6/A/56A19DD6-35FB-47A2-A9B2-74E66D269345/msrcorid.tar.gz

# %%
! tar -xvzf msrcorid.tar.gz

# %%
! mkdir dataset
! mkdir dataset/cows
! mkdir dataset/sheep 
! mkdir dataset/bicycle
! mkdir dataset/buildings
! mkdir dataset/chimneys
! mkdir dataset/doors 
! mkdir dataset/forks
! mkdir dataset/knives
! mkdir dataset/spoons
! mkdir dataset/miscellaneous
! mkdir dataset/signs 
! mkdir dataset/windows
! mkdir dataset/aeroplanes
! mkdir dataset/benches_and_chairs
! mkdir dataset/birds 
! mkdir dataset/cars 
! mkdir dataset/clouds 
! mkdir dataset/flowers
! mkdir dataset/leaves
! mkdir dataset/countryside
! mkdir dataset/office
! mkdir dataset/urban
! mkdir dataset/trees

# %%
! cp msrcorid/animals/cows/single/*.JPG dataset/cows/
! cp msrcorid/animals/cows/general/*.JPG dataset/cows/
! cp msrcorid/animals/sheep/single/*.JPG dataset/sheep/
! cp msrcorid/animals/sheep/general/*.JPG dataset/sheep/

! cp msrcorid/bicycles/side\ view\,\ single/*.JPG  dataset/bicycles/
! cp msrcorid/bicycles/general/*.JPG  dataset/bicycles/

! cp msrcorid/buildings/*.JPG dataset/buildings/
! cp msrcorid/chimneys/*.JPG dataset/chimneys/
! cp msrcorid/doors/*.JPG dataset/doors/

! cp msrcorid/kitchen_utensils/forks/*.JPG dataset/forks/
! cp msrcorid/kitchen_utensils/knives/*.JPG dataset/knives/
! cp msrcorid/kitchen_utensils/spoons/*.JPG dataset/spoons/

! cp msrcorid/miscellaneous/*.JPG dataset/miscellaneous/
! cp msrcorid/signs/*.JPG dataset/signs/
! cp msrcorid/windows/*.JPG dataset/windows/


! cp msrcorid/aeroplanes/single/*.JPG dataset/aeroplanes/
! cp msrcorid/aeroplanes/general/*.JPG dataset/aeroplanes/

! cp msrcorid/benches_and_chairs/*.JPG dataset/benches_and_chairs/


! cp msrcorid/birds/single/*.JPG dataset/birds/
! cp msrcorid/birds/general/*.JPG dataset/birds/

! cp msrcorid/cars/general/*.JPG dataset/cars/
! cp msrcorid/cars/front\ view/*.JPG dataset/cars/
! cp msrcorid/cars/rear\ view/*.JPG dataset/cars/
! cp msrcorid/cars/side\ view/*.JPG dataset/cars/


! cp msrcorid/clouds/*.JPG dataset/clouds/

! cp msrcorid/flowers/single/*.JPG dataset/flowers/
! cp msrcorid/flowers/general/*.JPG dataset/flowers/

! cp msrcorid/leaves/*.JPG dataset/leaves/


! cp msrcorid/trees/single/*.JPG dataset/trees/
! cp msrcorid/trees/general/*.JPG dataset/trees/

! cp msrcorid/scenes/countryside/*.JPG dataset/countryside/
! cp msrcorid/scenes/urban/*.JPG dataset/urban/
! cp msrcorid/scenes/office/*.JPG dataset/office/

# %% [markdown]
# ## Training

# %%
# For mxnet-gluon backend 
#from monk.gluon_prototype import prototype

# Using pytorch backend
from monk.pytorch_prototype import prototype

# For Keras backend
#from monk.keras_prototype import prototype

# %%
# Create Project and Experiment

gtf = prototype(verbose=1);
gtf.Prototype("Project-Image-Understanding", "Pytorch-Resnet50");

# %%
gtf.Default(dataset_path="dataset/",
            model_name="resnet50", 
            freeze_base_network=False,
            num_epochs=100);

# %% [markdown]
# ### How to change hyper parameters and models
#   - Docs - https://github.com/Tessellate-Imaging/monk_v1#4
#   - Examples - https://github.com/Tessellate-Imaging/monk_v1/tree/master/study_roadmaps/1_getting_started_roadmap

# %%
gtf.update_batch_size(32);
gtf.update_save_intermediate_models(False);

# Reload post updates
gtf.Reload();

# %%
#Start Training
gtf.Train();

#Read the training summary generated once you run the cell and training is completed

# %% [markdown]
# # Inference (Post training)

# %%
#Using pytorch backend 

# When installed using pip
from monk.pytorch_prototype import prototype

# %%
gtf = prototype(verbose=1);
gtf.Prototype("Project-Image-Understanding", "Pytorch-Resnet50", eval_infer=True);

# %%
img_name = "dataset/aeroplanes/166_6654.JPG"
predictions = gtf.Infer(img_name=img_name);
from IPython.display import Image
Image(filename=img_name)

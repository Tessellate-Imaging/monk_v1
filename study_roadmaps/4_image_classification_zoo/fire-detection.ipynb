# %% [markdown]
# # Goal
#
# - Make a fire-detection deep learning model using [Monk library](https://github.com/Tessellate-Imaging/monk_v1) and tranfer learning.
# - Comparing [mobilenet-v2](https://keras.io/api/applications/mobilenet/#mobilenetv2-function), [densenet121](https://keras.io/api/applications/densenet/#densenet121-function) and [densenet201](https://keras.io/api/applications/densenet/).
#
# ## Table of Content
# ### - Install Monk
# ### - Using pretrained model for fire detection
# ### - Training a classifier from scratch

# %% [markdown]
# ##  Install Monk
# ### Using pip (Recommended)
#
#   - colab (gpu)
#       - All bakcends: `pip install -U monk-colab`
#
#
#   - kaggle (gpu)
#       - All backends: `pip install -U monk-kaggle`
#
#
#   - cuda 10.2
#       - All backends: `pip install -U monk-cuda102`
#       - Gluon bakcned: `pip install -U monk-gluon-cuda102`
# 	  - Pytorch backend: `pip install -U monk-pytorch-cuda102`
#       - Keras backend: `pip install -U monk-keras-cuda102`
#
#
#   - cuda 10.1
#       - All backend: `pip install -U monk-cuda101`
# 	  - Gluon bakcned: `pip install -U monk-gluon-cuda101`
# 	  - Pytorch backend: `pip install -U monk-pytorch-cuda101`
# 	  - Keras backend: `pip install -U monk-keras-cuda101`
#
#
#   - cuda 10.0
#       - All backend: `pip install -U monk-cuda100`
# 	  - Gluon bakcned: `pip install -U monk-gluon-cuda100`
# 	  - Pytorch backend: `pip install -U monk-pytorch-cuda100`
# 	  - Keras backend: `pip install -U monk-keras-cuda100`
#
#
#   - cuda 9.2
#       - All backend: `pip install -U monk-cuda92`
# 	  - Gluon bakcned: `pip install -U monk-gluon-cuda92`
# 	  - Pytorch backend: `pip install -U monk-pytorch-cuda92`
# 	  - Keras backend: `pip install -U monk-keras-cuda92`
#
#
#   - cuda 9.0
#       - All backend: `pip install -U monk-cuda90`
# 	  - Gluon bakcned: `pip install -U monk-gluon-cuda90`
# 	  - Pytorch backend: `pip install -U monk-pytorch-cuda90`
# 	  - Keras backend: `pip install -U monk-keras-cuda90`
#
#
#   - cpu
#       - All backend: `pip install -U monk-cpu`
# 	  - Gluon bakcned: `pip install -U monk-gluon-cpu`
# 	  - Pytorch backend: `pip install -U monk-pytorch-cpu`
# 	  - Keras backend: `pip install -U monk-keras-cpu`

# %% [markdown]
# ## Install Monk Manually (Not recommended)
#
# ### Step 1: Clone the library
#  - git clone https://github.com/Tessellate-Imaging/monk_v1.git
#
#
#
#
# ### Step 2: Install requirements
#  - Linux
#      - Cuda 9.0
#          - `cd monk_v1/installation/Linux && pip install -r requirements_cu90.txt`
#      - Cuda 9.2
#          - `cd monk_v1/installation/Linux && pip install -r requirements_cu92.txt`
#      - Cuda 10.0
#          - `cd monk_v1/installation/Linux && pip install -r requirements_cu100.txt`
#      - Cuda 10.1
#          - `cd monk_v1/installation/Linux && pip install -r requirements_cu101.txt`
#      - Cuda 10.2
#          - `cd monk_v1/installation/Linux && pip install -r requirements_cu102.txt`
#      - CPU (Non gpu system)
#          - `cd monk_v1/installation/Linux && pip install -r requirements_cpu.txt`
#
#
#   - Windows
#      - Cuda 9.0 (Experimental support)
#          - `cd monk_v1/installation/Windows && pip install -r requirements_cu90.txt`
#      - Cuda 9.2 (Experimental support)
#          - `cd monk_v1/installation/Windows && pip install -r requirements_cu92.txt`
#      - Cuda 10.0 (Experimental support)
#          - `cd monk_v1/installation/Windows && pip install -r requirements_cu100.txt`
#      - Cuda 10.1 (Experimental support)
#          - `cd monk_v1/installation/Windows && pip install -r requirements_cu101.txt`
#      - Cuda 10.2 (Experimental support)
#          - `cd monk_v1/installation/Windows && pip install -r requirements_cu102.txt`
#      - CPU (Non gpu system)
#          - `cd monk_v1/installation/Windows && pip install -r requirements_cpu.txt`
#
#
#   - Mac
#      - CPU (Non gpu system)
#          - `cd monk_v1/installation/Mac && pip install -r requirements_cpu.txt`
#
#
#   - Misc
#       - Colab (GPU)
#           - `cd monk_v1/installation/Misc && pip install -r requirements_colab.txt`
#       - Kaggle (GPU)
#           - `cd monk_v1/installation/Misc && pip install -r requirements_kaggle.txt`
#
#
#
# ### Step 3: Add to system path (Required for every terminal or kernel run)
#  - `import sys`
#  - `sys.path.append("monk_v1/");`

# %%
! pip install -U monk-cuda100

# %% [markdown]
# ## Used trained classifier for demo

# %%
#download the pre-trained models
! wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1tTJ6KEkzv1GIRsvo_-wI6YQh7iztbDCW' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1tTJ6KEkzv1GIRsvo_-wI6YQh7iztbDCW" -O cls_fire_trained.zip && rm -rf /tmp/cookies.txt

# %%
! unzip -qq cls_fire_trained.zip

# %%
#Using keras backend
from monk.keras_prototype import prototype

# %%
keras_gtf = prototype(verbose=1);
keras_gtf.Prototype("Fire-detection", "mobilenet_v2", eval_infer=True);

#uncomment to use these model
#keras_gtf.Prototype("Fire-detection", "densenet121", eval_infer=True);
#keras_gtf.Prototype("Fire-detection", "densenet201", eval_infer=True);
# Out:
# Keras Version: 2.3.0
# Tensorflow Version: 2.0.0
#
# Model Details
#     Loading model - workspace/Fire-detection/mobilenet_v2/output/models/final.h5
#     Model loaded!
#
# Experiment Details
#     Project: Fire-detection
#     Experiment: mobilenet_v2
#     Dir: /home/ubuntu/workspace/Fire-detection/mobilenet_v2/

# %%
img_name = "workspace/Fire-detection/test/1.jpg"
predictions = keras_gtf.Infer(img_name=img_name)
#Display 
from IPython.display import Image
Image(filename=img_name, height=300, width=300)
# Out:
# Prediction
#     Image name:         workspace/Fire-detection/test/1.jpg
#     Predicted class:      fire_images
#     Predicted score:      0.9768148064613342

# %%
img_name = "workspace/Fire-detection/test/9.jpg"
predictions = keras_gtf.Infer(img_name=img_name)
#Display 
from IPython.display import Image
Image(filename=img_name, height=300, width=300)
# Out:
# Prediction
#     Image name:         workspace/Fire-detection/test/9.jpg
#     Predicted class:      fire_images
#     Predicted score:      0.9212136268615723

# %%
img_name = "workspace/Fire-detection/test/5.jpg"
predictions = keras_gtf.Infer(img_name=img_name)
#Display 
from IPython.display import Image
Image(filename=img_name, height=300, width=300)
# Out:
# Prediction
#     Image name:         workspace/Fire-detection/test/5.jpg
#     Predicted class:      fire_images
#     Predicted score:      0.607664167881012

# %%
img_name = "workspace/Fire-detection/test/11.jpg"
predictions = keras_gtf.Infer(img_name=img_name)
#Display 
from IPython.display import Image
Image(filename=img_name, height=300, width=300)
# Out:
# Prediction
#     Image name:         workspace/Fire-detection/test/11.jpg
#     Predicted class:      non_fire_images
#     Predicted score:      0.9889940619468689

# %%
img_name = "workspace/Fire-detection/test/14.jpg"
predictions = keras_gtf.Infer(img_name=img_name)
#Display 
from IPython.display import Image
Image(filename=img_name, height=300, width=300)
# Out:
# Prediction
#     Image name:         workspace/Fire-detection/test/14.jpg
#     Predicted class:      non_fire_images
#     Predicted score:      0.9736764430999756

# %%
img_name = "workspace/Fire-detection/test/8.jpg"
predictions = keras_gtf.Infer(img_name=img_name)
#Display 
from IPython.display import Image
Image(filename=img_name, height=300, width=300)
# Out:
# Prediction
#     Image name:         workspace/Fire-detection/test/8.jpg
#     Predicted class:      fire_images
#     Predicted score:      0.7942782640457153

# %% [markdown]
# ## Training custom classifier from scratch

# %% [markdown]
# ### Upcoming contents
# - Loading the Dataset
# - Importing keras backend
# - Training model using mobilenet_v2 as transfer learning architecture
# - Training model using desnenet121 as transfer learning architecture
# - Training model using densenet201 as transfer learning architecture
# - Comparing all the models.

# %% [markdown]
# ### Loading the Dataset

# %%
#since dataset is from kaggle we have to install it
! pip install -q kaggle

# %%
! mkdir ~/.kaggle
! cp kaggle.json ~/.kaggle/
! chmod 600 ~/.kaggle/kaggle.json

# %%
! kaggle datasets download -d ritupande/fire-detection-from-cctv

# %%
! unzip -qq fire-detection-from-cctv.zip -d fire-dataset

# %% [markdown]
# ### Importing keras backend

# %%
#Using keras backend
#when installed using pip
from monk.keras_prototype import prototype


# When installed manually (Uncomment the following)
#import os
#import sys
#sys.path.append("monk_v1/");
#sys.path.append("monk_v1/monk/");
#from monk.keras_prototype import prototype

# %% [markdown]
# ### Training model using mobilenet_v2 as transfer learning architecture

# %%
# Load experiment
keras_gtf = prototype(verbose=1);
keras_gtf.Prototype("Fire-detection", "mobilenet_v2");

# Insert data and set params in default mode
keras_gtf.Default(dataset_path="fire-dataset/fire_dataset", 
                  model_name="mobilenet_v2", 
                  freeze_base_network=False,
                  num_epochs=15)

# %%
#Start Training
keras_gtf.Train();

#Read the training summary generated once you run the cell and training is completed

# %%
# Load for test
keras_gtf = prototype(verbose=1);
keras_gtf.Prototype("Fire-detection", "mobilenet_v2", eval_infer=True);

# %%
img_name = "workspace/Fire-detection/test/1.jpg"
predictions = keras_gtf.Infer(img_name=img_name)
#Display 
from IPython.display import Image
Image(filename=img_name, height=300, width=300)
# Out:
# Prediction
#     Image name:         workspace/Fire-detection/test/1.jpg
#     Predicted class:      fire_images
#     Predicted score:      0.9768148064613342

# %%
img_name = "workspace/Fire-detection/test/14.jpg"
predictions = keras_gtf.Infer(img_name=img_name )
#Display 
from IPython.display import Image
Image(filename=img_name, height=300, width=300)
# Out:
# Prediction
#     Image name:         workspace/Fire-detection/test/14.jpg
#     Predicted class:      non_fire_images
#     Predicted score:      0.9736764430999756

# %% [markdown]
# ### Training model using desnenet121 as transfer learning architecture

# %%
# Load experiment
keras_gtf = prototype(verbose=1);
keras_gtf.Prototype("Fire-detection", "densenet121");

# Insert data and set params in default mode
keras_gtf.Default(dataset_path="fire-dataset/fire_dataset", 
                  model_name="densenet121", 
                  freeze_base_network=False, 
                  num_epochs=15)

# %%
#Start Training
keras_gtf.Train();

#Read the training summary generated once you run the cell and training is completed

# %%
#Load for test
keras_gtf = prototype(verbose=1);
keras_gtf.Prototype("Fire-detection", "densenet121", eval_infer=True);
# Out:
# Keras Version: 2.3.0
# Tensorflow Version: 2.0.0
#
# Model Details
#     Loading model - workspace/Fire-detection/densenet121/output/models/final.h5
#     Model loaded!
#
# Experiment Details
#     Project: Fire-detection
#     Experiment: densenet121
#     Dir: /home/ubuntu/workspace/Fire-detection/densenet121/

# %%
img_name = "workspace/Fire-detection/test/1.jpg"
predictions = keras_gtf.Infer(img_name=img_name)
#Display 
from IPython.display import Image
Image(filename=img_name, height=300, width=300)
# Out:
# Prediction
#     Image name:         workspace/Fire-detection/test/1.jpg
#     Predicted class:      fire_images
#     Predicted score:      0.9251481890678406

# %%
img_name = "workspace/Fire-detection/test/10.jpg"
predictions = keras_gtf.Infer(img_name=img_name)
#Display 
from IPython.display import Image
Image(filename=img_name, height=300, width=300)
# Out:
# Prediction
#     Image name:         workspace/Fire-detection/test/10.jpg
#     Predicted class:      non_fire_images
#     Predicted score:      0.9748664498329163

# %% [markdown]
# ### Training model using desnenet201 as transfer learning architecture

# %%
#Load experiment
keras_gtf = prototype(verbose=1);
keras_gtf.Prototype("Fire-detection", "densenet201");

# Insert data and set params in default mode
keras_gtf.Default(dataset_path="fire-dataset/fire_dataset", 
                  model_name="densenet201", 
                  freeze_base_network=False, 
                  num_epochs=15)

# %%
#Start Training
keras_gtf.Train();

#Read the training summary generated once you run the cell and training is completed

# %%
keras_gtf = prototype(verbose=1);
keras_gtf.Prototype("Fire-detection", "densenet201", eval_infer=True);
# Out:
# Keras Version: 2.3.0
# Tensorflow Version: 2.0.0
#
# Model Details
#     Loading model - workspace/Fire-detection/densenet201/output/models/final.h5
# WARNING:tensorflow:From /home/ubuntu/.virtualenvs/fire/lib/python3.6/site-packages/monk/tf_keras_1/models/common.py:224: The name tf.keras.backend.set_session is deprecated. Please use tf.compat.v1.keras.backend.set_session instead.
#
#     Model loaded!
#
# Experiment Details
#     Project: Fire-detection
#     Experiment: densenet201
#     Dir: /home/ubuntu/workspace/Fire-detection/densenet201/

# %%
img_name = "workspace/Fire-detection/test/1.jpg"
predictions = keras_gtf.Infer(img_name=img_name)
#Display 
from IPython.display import Image
Image(filename=img_name, height=300, width=300)
# Out:
# Prediction
#     Image name:         workspace/Fire-detection/test/1.jpg
#     Predicted class:      fire_images
#     Predicted score:      0.9702081680297852

# %%
img_name = "workspace/Fire-detection/test/10.jpg"
predictions = keras_gtf.Infer(img_name=img_name)
#Display 
from IPython.display import Image
Image(filename=img_name, height=300, width=300)
# Out:
# Prediction
#     Image name:         workspace/Fire-detection/test/10.jpg
#     Predicted class:      non_fire_images
#     Predicted score:      0.9989756345748901

# %% [markdown]
# ### Comparing all the experiments.
# Using comparison class of Monk library.

# %%
# Invoke the comparison class
from monk.compare_prototype import compare

# %%
gtf = compare(verbose=1);
gtf.Comparison("Comparison-fire-detector");
# Out:
# Comparison: - Comparison-fire-detector

# %%
gtf.Add_Experiment("Fire-detection", "mobilenet_v2");
gtf.Add_Experiment("Fire-detection", "densenet121");
gtf.Add_Experiment("Fire-detection", "densenet201");
# Out:
# Project - Fire-detection, Experiment - mobilenet_v2 added
# Project - Fire-detection, Experiment - densenet121 added
# Project - Fire-detection, Experiment - densenet201 added

# %%
gtf.Generate_Statistics();
# Out:
# Generating statistics...
# Generated

# %% [markdown]
# ### Visualize and study comparison metrics

# %% [markdown]
# - Training Accuracy Curves

# %%
from IPython.display import Image

Image(filename="workspace/comparison/Comparison-fire-detector/train_accuracy.png")

# %% [markdown]
# - Training Loss Curves

# %%
Image(filename="workspace/comparison/Comparison-fire-detector/train_loss.png")

# %% [markdown]
# - Validation Accuracy Curves

# %%
Image(filename="workspace/comparison/Comparison-fire-detector/val_accuracy.png")

# %% [markdown]
# - Validation Loss Curves

# %%
from IPython.display import Image
Image(filename="workspace/comparison/Comparison-fire-detector/val_loss.png")

# %% [markdown]
# - Training time taken

# %%
Image(filename="workspace/comparison/Comparison-fire-detector/stats_training_time.png")

# %% [markdown]
# - Best validation accuracy.

# %%
Image(filename="workspace/comparison/Comparison-fire-detector/stats_best_val_acc.png")

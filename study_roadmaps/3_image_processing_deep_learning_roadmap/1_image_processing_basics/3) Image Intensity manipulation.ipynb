# %% [markdown]
# <a href="https://colab.research.google.com/github/Tessellate-Imaging/monk_v1/blob/master/study_roadmaps/3_image_processing_deep_learning_roadmap/1_image_processing_basics/3)%20Image%20Intensity%20manipulation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Topics to cover
#
#
# ## [0. Install](#0)
#
#
# ## [1. Mathematical operations](#1)
#         - intensity manipulation
#         - mean subtraction
#         - negative image
#         - Adding two images
#         - Subtracting two images
#
#
# ## [2. Brightness](#2)
#         - What is brightness in image
#         - Advantages of manipulating brightness
#         - Manipulate brightness in image
#
#
# ## [3. Contrast](#3)
#         - What is contrast in image
#         - How is contrast different from brightness
#         - Advantages of manipulating contrast
#         - Manipulate contrast in image
#
#
# ## [4. Gamma manipulation](#4)
#         - What is gamma in image
#         - Apply gamma correction in image
#
#
# ## [5. Histogram equalization](#5)
#     - What is histogram of an image
#     - What is histogram equalization
#     - What is the need for histogram equalization
#
#
# ## [Coding Assignment - Instagram style color pallete](#6)

# %% [markdown]
# <a id='0'></a>
# # Install Monk
#
#  - git clone https://github.com/Tessellate-Imaging/monk_v1.git
#
#  - cd monk_v1/installation/Linux && pip install -r requirements_cu9.txt
#      - (Select the requirements file as per OS and CUDA version)

# %%
# !git clone https://github.com/Tessellate-Imaging/monk_v1.git

# %%
# If using Colab install using the commands below
# !cd monk_v1/installation/Misc && pip install -r requirements_colab.txt

# If you want to install only necessary libraries for this tutoria
#!cd monk_v1/installation/Misc && pip install -r requirements_img_proc.txt


# If using Kaggle uncomment the following command
#!cd monk_v1/installation/Misc && pip install -r requirements_kaggle.txt

# Select the requirements file as per OS and CUDA version when using a local system or cloud
#!cd monk_v1/installation/Linux && pip install -r requirements_cu9.txt

# %%
# Imports
import os
import sys
sys.path.append("monk_v1/monk/");

# %%
# %matplotlib inline

# %%
folder_path = "monk_v1/study_roadmaps/3_image_processing_deep_learning_roadmap/1_image_processing_basics/"

# %% [markdown]
# <a id='1'></a>
# # Mathematical operations

# %%
print("Use slider to change slides")
# Slide section 1
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets
from IPython.display import display
from PIL import Image


sl = widgets.IntSlider(value=1, min=1, max=2);

def f(slide_num):
    img_name = folder_path + "imgs/chapter3/slide{}.jpg".format(slide_num);
    img = Image.open(img_name);
    
    display(img);

interact(f, slide_num=sl);
# Out:
# interactive(children=(IntSlider(value=1, description='slide_num', max=2, min=1), Output()), _dom_classes=('wid…

# %% [markdown]
# ### Intensity manipulation on grayscale images

# %% [markdown]
# ## DIY CODING

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

# Load an image named "imgs/chapter3/man.jpg" as grayscale
img =

# %% [markdown]
# ### Quiz - 1
#  - What flag was used while loading the image?

# %%
print("Input image shape - {}".format(img.shape));
plt.imshow(img, cmap = "gray");
plt.show()
# Out:
# Input image shape - (256, 256)

# %%
# Adding a constant value to input image using numpy
# Concentrate on the distortions
img = cv2.imread("imgs/chapter3/man.jpg", 0);

################################FOCUS######################################
img = np.add(img, 120);
###########################################################################


plt.imshow(img, cmap = "gray");
plt.show()

# %% [markdown]
# ### Quiz - 2
#  - Why did the image pixels get distorted?

# %%
# Adding a constant value to input image using opencv
# Now look at the same addition with cv2.add
# What has changed here?
# cv2.add
# Adding an imge of same size with all values as 120

img = cv2.imread(folder_path + "imgs/chapter3/man.jpg", 0);

###############################FOCUS####################################
img = cv2.add(img, 120);
########################################################################

plt.imshow(img, cmap = "gray");
plt.show()

# %%
# Subtracting a constant value to input image using numpy
# Concentrate on the distortions
img = cv2.imread(folder_path + "imgs/chapter3/man.jpg", 0);

###############################FOCUS#############################################
img = np.subtract(img, 120);
#################################################################################


plt.imshow(img, cmap = "gray");
plt.show()

# %%
# Subtracting a constant value to input image using opencv
img = cv2.imread(folder_path + "imgs/chapter3/man.jpg", 0);

###################################FOCUS#############################################
img = cv2.subtract(img, 120);
#####################################################################################


plt.imshow(img, cmap = "gray");
plt.show()

# %% [markdown]
# ## Image Intensity Manipulation

# %%
# Interactive demo - 1
# Adding subtracting constant values from an\ grayscale image
from matplotlib import pyplot as plt
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets
import cv2
import numpy as np

sl1 = widgets.IntSlider(value=0, min=-150, max=150, step=30);



def f(constant):
    img = cv2.imread(folder_path + "imgs/chapter3/man.jpg", 0);
    
    
    #################################FOCUS#######################################
    img = cv2.add(img, constant);
    #############################################################################
    
    f = plt.figure(figsize=(8,8))
    plt.imshow(img, cmap = "gray")
    plt.show()

interact(f, constant=sl1);
# Out:
# interactive(children=(IntSlider(value=0, description='constant', max=150, min=-150, step=30), Output()), _dom_…

# %% [markdown]
# ## Channel Intensity Manipulation

# %%
# Interactive demo - 2
# Adding subtracting constant values to/from a RGB image

from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets
import cv2
import numpy as np

sl1 = widgets.IntSlider(value=0, min=-150, max=150, step=30);
sl2 = widgets.IntSlider(value=0, min=-150, max=150, step=30);
sl3 = widgets.IntSlider(value=0, min=-150, max=150, step=30);



def f(b_constant, g_constant, r_constant):
    img = cv2.imread(folder_path + "imgs/chapter3/castle.png");
    
    #################################FOCUS#######################################
    b, g, r = cv2.split(img)
    b = cv2.add(b, b_constant)
    g = cv2.add(g, g_constant)
    r = cv2.add(r, r_constant)
    #############################################################################
    
    img = cv2.merge((r,g,b))
    
    plt.figure(figsize = (8,8))
    plt.imshow(img)
    plt.show()

interact(f, b_constant=sl1, g_constant=sl2, r_constant=sl3);
# Out:
# interactive(children=(IntSlider(value=0, description='b_constant', max=150, min=-150, step=30), IntSlider(valu…

# %%
# Where is

# %% [markdown]
# ### Subtracting its mean from an image

# %%
print("Use slider to change slides")
# Slide section 2
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets
from IPython.display import display
from PIL import Image


sl = widgets.IntSlider(value=3, min=3, max=3);

def f(slide_num):
    img_name = folder_path + "imgs/chapter3/slide{}.jpg".format(slide_num);
    img = Image.open(img_name);
    
    display(img);

interact(f, slide_num=sl);
# Out:
# interactive(children=(IntSlider(value=3, description='slide_num', max=3, min=3), Output()), _dom_classes=('wid…

# %%
# Grayscale image
import numpy as np
import cv2
from matplotlib import pyplot as plt
img = cv2.imread(folder_path + "imgs/chapter3/man.jpg", 0); # read the image as grayscale

# %%
# np.mean
# cv2.subtract
mean = np.mean(img);
img_out = cv2.subtract(img, mean);

# %%
f = plt.figure(figsize=(15,15))
f.add_subplot(1, 2, 1).set_title('Original Image');
plt.imshow(img, cmap = "gray");
f.add_subplot(1, 2, 2).set_title('Mean subtracted image');
plt.imshow(img_out, cmap = "gray");
plt.show()

# %% [markdown]
# ### Quiz-3
#  - Code as per the instructions given below

# %% [markdown]
# ## DIY CODING

# %%
# Color image
import numpy as np
import cv2
from matplotlib import pyplot as plt
img = cv2.imread(folder_path + "imgs/chapter3/castle.png", -1); # read the image as grayscale



# Step -1: Write the code to split the image into its channels



# Step - 2-a: Write the code to calculate mean of b channel

# Step - 2-b: Write the code to subtract mean of b channel from the b channel


# Step - 3-a: Write the code to calculate mean of g channel

# Step - 3-b: Write the code to subtract mean of g channel from the g channel


# Step - 4-a: Write the code to calculate mean of r channel

# Step - 4-b: Write the code to subtract mean of r channel from the r channel


# Merge the outputs of steps 2-b, 3-b, and 4-b


img_out = cv2.merge((r, g, b));

f = plt.figure(figsize=(15,15))
f.add_subplot(1, 2, 1).set_title('Original Image');
plt.imshow(img[:, :, ::-1]);
f.add_subplot(1, 2, 2).set_title('Mean subtracted image');
plt.imshow(img_out);
plt.show()

# %% [markdown]
# ### Negative images

# %%
# negative of grayscale
import numpy as np
import cv2
from matplotlib import pyplot as plt
img = cv2.imread(folder_path + "imgs/chapter3/man.jpg", 0); # read the image as grayscale

# %%
#cv2.subtract
img_out = cv2.subtract(255, img);

# %% [markdown]
# ### Quiz-4
#  - What is the difference between the current subtraction with the previous ones?

# %%
f = plt.figure(figsize=(15,15))
f.add_subplot(1, 2, 1).set_title('Original Image');
plt.imshow(img, cmap = "gray");
f.add_subplot(1, 2, 2).set_title('Negative image');
plt.imshow(img_out, cmap = "gray");
plt.show()

# %%
# negative of rgb images
import numpy as np
import cv2
from matplotlib import pyplot as plt
img = cv2.imread(folder_path + "imgs/chapter3/castle.png", -1); 
img_out = 255 - img;

f = plt.figure(figsize=(15,15))
f.add_subplot(1, 2, 1).set_title('Original Image');
plt.imshow(img[:,:,::-1]);
f.add_subplot(1, 2, 2).set_title('Negative image');
plt.imshow(img_out[:,:,::-1]);
plt.show()

# %% [markdown]
# ### Adding two images

# %%
# Direct adding
import numpy as np
import cv2
from matplotlib import pyplot as plt

# %%
img1 = cv2.imread(folder_path + "imgs/chapter3/castle.png", -1); 
img1 = cv2.resize(img1, (256, 256));
img2 = cv2.imread(folder_path + "imgs/chapter3/tessellate.jpg", -1);
img2 = cv2.resize(img2, (256, 256));

# %%
img_out = cv2.add(img1, img2);

# %%
f = plt.figure(figsize=(8,8))
plt.imshow(img_out[:,:,::-1]);
plt.show()

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
img1 = cv2.imread(folder_path + "imgs/chapter3/castle.png", -1); 
img1 = cv2.resize(img1, (256, 256));
img2 = cv2.imread(folder_path + "imgs/chapter3/tessellate.jpg", -1);
img2 = cv2.resize(img2, (256, 256));

# %%
# cv2.addWeighted
# Like a faint watermark
img_out = cv2.addWeighted(img1,0.7,img2,0.3,0);

# %%
f = plt.figure(figsize=(8,8))
plt.imshow(img_out[:,:,::-1]);
plt.show()

# %%
# Interactive demo - 3
# Importance of weights in image blending

from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets
import cv2
import numpy as np

sl1 = widgets.FloatSlider(value=0.5, min=0.0, max=1.0, step=0.1);
sl2 = widgets.FloatSlider(value=0.5, min=0.0, max=1.0, step=0.1);



def f(weight_1, weight_2):
    img1 = cv2.imread(folder_path + "imgs/chapter3/castle.png", -1); 
    img1 = cv2.resize(img1, (256, 256));
    img2 = cv2.imread(folder_path + "imgs/chapter3/tessellate.jpg", -1);
    img2 = cv2.resize(img2, (256, 256));
    
    
    ######################################FOCUS######################
    img_out = cv2.addWeighted(img1,weight_1,img2,weight_2,0);
    #################################################################
    
    
    f = plt.figure(figsize=(8,8))
    plt.imshow(img_out[:,:,::-1]);
    plt.show()

interact(f, weight_1=sl1, weight_2=sl2);
# Out:
# interactive(children=(FloatSlider(value=0.5, description='weight_1', max=1.0), FloatSlider(value=0.5, descript…

# %% [markdown]
# ### Subtracting two images

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
img1 = cv2.imread(folder_path + "imgs/chapter3/background.png", -1); 
img2 = cv2.imread(folder_path + "imgs/chapter3/foreground.png", -1);


img_out = cv2.subtract(img2, img1);


f = plt.figure(figsize=(15,10))
f.add_subplot(2, 2, 1).set_title('Background Image');
plt.imshow(img1[:, :, ::-1])
f.add_subplot(2, 2, 2).set_title('Background image with some object');
plt.imshow(img2[:, :, ::-1])
f.add_subplot(2, 2, 3).set_title('Subtracted image');
plt.imshow(img_out[:, :, ::-1])
plt.show()

# %% [markdown]
# <a id='2'></a>
# # Brightness

# %%
print("Use slider to change slides")
# Slide section 2
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets
from IPython.display import display
from PIL import Image


sl = widgets.IntSlider(value=4, min=4, max=4);

def f(slide_num):
    img_name = folder_path + "imgs/chapter3/slide{}.jpg".format(slide_num);
    img = Image.open(img_name);
    
    display(img);

interact(f, slide_num=sl);
# Out:
# interactive(children=(IntSlider(value=4, description='slide_num', max=4, min=4), Output()), _dom_classes=('wid…

# %% [markdown]
# ### Brightness adjustment in opencv

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
img = cv2.imread(folder_path + 'imgs/chapter3/outdoor.jpg')

# %%
value = 100 #Increase or decrease brightness by this value

hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
hsv[:,:,2] = cv2.add(hsv[:,:,2], value)

# %% [markdown]
# ### Quiz-5
#  - Why the value 2 in hsv[:,:,2] is being used?

# %%
img_out = cv2.cvtColor(hsv, cv2.COLOR_HSV2BGR)

# %%
f = plt.figure(figsize=(15,15))
f.add_subplot(1, 2, 1).set_title('Original Image');
plt.imshow(img[:, :, ::-1])
f.add_subplot(1, 2, 2).set_title('Brightness manipulated image');
plt.imshow(img_out[:, :, ::-1])
plt.show()

# %% [markdown]
# ### Quiz-6
#  - Code as per the instructions mentioned below

# %% [markdown]
# ## DIY CODING

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
img = cv2.imread(folder_path + 'imgs/chapter3/outdoor.jpg')

value = 100;
hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
hsv[:,:,2] = cv2.add(hsv[:,:,2], value)
img_out1 = cv2.cvtColor(hsv, cv2.COLOR_HSV2BGR)


# Write a code to add 100 value to the entire image using a relevant OpenCV function
# Store the output as img_out2

f = plt.figure(figsize=(15,15))
f.add_subplot(1, 2, 1).set_title('Brightness manipulated image');
plt.imshow(img_out1[:, :, ::-1])
f.add_subplot(1, 2, 2).set_title('Simple value added image');
plt.imshow(img_out1[:, :, ::-1])
plt.show()

# %% [markdown]
# ## Brightness Manipulation

# %%
# Interactive demo - 3
# Understand how brightness changes affect appearnce using OpenCV
from matplotlib import pyplot as plt
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets
import cv2
import numpy as np

sl1 = widgets.IntSlider(value=0, min=-150, max=150, step=10);


def f(value):
    img = cv2.imread(folder_path + 'imgs/chapter3/outdoor.jpg')
    hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
    hsv[:,:,2] = cv2.add(hsv[:,:,2], value)
    img_out = cv2.cvtColor(hsv, cv2.COLOR_HSV2BGR)
    f = plt.figure(figsize=(10,10))
    plt.imshow(img_out[:,:,::-1]);
    plt.show()

interact(f, value=sl1);
# Out:
# interactive(children=(IntSlider(value=0, description='value', max=150, min=-150, step=10), Output()), _dom_cla…

# %% [markdown]
# <a id='3'></a>
# # Contrast

# %%
print("Use slider to change slides")
# Slide section 3
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets
from IPython.display import display
from PIL import Image


sl = widgets.IntSlider(value=5, min=5, max=5);

def f(slide_num):
    img_name = folder_path + "imgs/chapter3/slide{}.jpg".format(slide_num);
    img = Image.open(img_name);
    
    display(img);

interact(f, slide_num=sl);
# Out:
# interactive(children=(IntSlider(value=5, description='slide_num', max=5, min=5), Output()), _dom_classes=('wid…

# %% [markdown]
# ### Manipulating contrast in an image

# %%
from PIL import Image, ImageEnhance
from matplotlib import pyplot as plt

img = Image.open(folder_path + "imgs/chapter3/outdoor.jpg");

# %%
enhancer = ImageEnhance.Contrast(img)
out = enhancer.enhance(factor=1.25)

# %%
f = plt.figure(figsize=(15,15))
f.add_subplot(2, 1, 1).set_title('Original Image');
plt.imshow(img)
f.add_subplot(2, 1, 2).set_title('Contrast manipulated image');
plt.imshow(out)
plt.show()

# %% [markdown]
# ## Contrast Manipulation

# %%
# Interactive demo - 4
# Understand how contrast changes affect appearnce using PILLOW

from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets
from PIL import Image, ImageEnhance
import numpy as np

sl1 = widgets.FloatSlider(value=1.0, min=1.0, max=5.0, step=0.5);

def f(factor):
    img = Image.open(folder_path + "imgs/chapter3/outdoor.jpg");
    enhancer = ImageEnhance.Contrast(img)
    
    #########################FOCUS####################
    out = enhancer.enhance(factor=factor)
    ##################################################
    
    
    f = plt.figure(figsize=(12, 12))
    plt.imshow(out);
    plt.show()

interact(f, factor=sl1);
# Out:
# interactive(children=(FloatSlider(value=1.0, description='factor', max=5.0, min=1.0, step=0.5), Output()), _do…

# %% [markdown]
# <a id='4'></a>
# # Gamma

# %%
print("Use slider to change slides")
# Slide section 4
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets
from IPython.display import display
from PIL import Image


sl = widgets.IntSlider(value=6, min=6, max=6);

def f(slide_num):
    img_name = folder_path + "imgs/chapter3/slide{}.jpg".format(slide_num);
    img = Image.open(img_name);
    
    display(img);

interact(f, slide_num=sl);
# Out:
# interactive(children=(IntSlider(value=6, description='slide_num', max=6, min=6), Output()), _dom_classes=('wid…

# %% [markdown]
# ### Manipluating gamma using opencv

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
img = cv2.imread(folder_path + 'imgs/chapter3/indoor.jpg')

# %%
# Apply Gamma=2.2 on the normalised image and then multiply by scaling constant (For 8 bit, c=255)

# Normalize image, pixels to 0-1
# Multiple by gamma
# Re-factor the image pixels to have value from 0-255

img_out = np.array(255*(img/255)**2.2,dtype='uint8')

# %%
f = plt.figure(figsize=(15,15))
f.add_subplot(2, 1, 1).set_title('Original Image');
plt.imshow(img[:, :, ::-1])
f.add_subplot(2, 1, 2).set_title('Gamma manipulated image');
plt.imshow(img_out[:, :, ::-1])
plt.show()

# %%
# Interactive demo - 5
# Understand how gamma changes affect appearnce using opencv

from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets
import cv2
import numpy as np

sl1 = widgets.FloatSlider(value=1.0, min=0.1, max=3.0, step=0.2);



def f(gamma):
    img = cv2.imread(folder_path + 'imgs/chapter3/indoor.jpg')
    img_out = np.array(255*(img/255)**gamma,dtype='uint8')
    f = plt.figure(figsize=(8,8))
    plt.imshow(img_out[:,:,::-1]);
    plt.show()

interact(f, gamma=sl1);

# %% [markdown]
# <a id='5'></a>
# # Histogram equalization

# %%
print("Use slider to change slides")
# Slide section 5
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets
from IPython.display import display
from PIL import Image


sl = widgets.IntSlider(value=7, min=7, max=8);

def f(slide_num):
    img_name = folder_path + "imgs/chapter3/slide{}.jpg".format(slide_num);
    img = Image.open(img_name);
    
    display(img);

interact(f, slide_num=sl);
# Out:
# interactive(children=(IntSlider(value=7, description='slide_num', max=8, min=7), Output()), _dom_classes=('wid…

# %% [markdown]
# ### Histogram creation using numpy

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
img = cv2.imread(folder_path + "imgs/chapter3/outdoor.jpg", 0)

# %%
# Ravel falttens the 2d array to 1d array
# 256 - total number of bins
plt.hist(img.ravel(),256,[0,256])

plt.title("Histogram for original image")
plt.show()

# %%
# Study the histogram above

# %% [markdown]
# ### Histogram Equalization using OpenCV

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
img = cv2.imread(folder_path + "imgs/chapter3/outdoor.jpg", 0)

# %%
# cv2.equalizeHist
img_out = cv2.equalizeHist(img)

# %%
plt.hist(img_out.ravel(),256,[0,256])  # arguments are passed to np.histogram
plt.title("Histogram with 'auto' bins")
plt.show()

# %%
f = plt.figure(figsize=(15,15))
f.add_subplot(2, 1, 1).set_title('Original Image');
plt.imshow(img, cmap="gray")
f.add_subplot(2, 1, 2).set_title('Histogram equalized image');
plt.imshow(img_out, cmap="gray")
plt.show()

# %% [markdown]
# ## DIY CODING

# %% [markdown]
# <a id='6'></a>
# # Coding Assignment - Instagram style color pallete
#     - Take Color pallete from source image
#     - Apply it to a target image

# %%
# Goal
import numpy as np
import cv2
from matplotlib import pyplot as plt
img = cv2.imread(folder_path + "imgs/chapter3/autumn_fallingwater.png", 1)

plt.figure(figsize=(15, 15))
plt.imshow(img[:,:,::-1])
plt.show()

# %%
# Goal
import numpy as np
import cv2
from matplotlib import pyplot as plt
img = cv2.imread(folder_path + "imgs/chapter3/sunset_ocean.png", 1)

plt.figure(figsize=(15, 15))
plt.imshow(img[:,:,::-1])
plt.show()

# %%
# Goal
import numpy as np
import cv2
from matplotlib import pyplot as plt
img = cv2.imread(folder_path + "imgs/chapter3/woods_storm.png", 1)

plt.figure(figsize=(15, 15))
plt.imshow(img[:,:,::-1])
plt.show()

# %%
# Compute standard statistical measures

# This image is expected to take an image in LAB color space
def image_stats(image):
    
    # STEP - 1: Split image into its component and store into variables - l, a, b
    # Write code here
    
    
    
    # STEP - 2: calulate mean and standard deviation of each channel l, a, b
    # Hint use .mean() and .std() numpy functions
    # Store the outputs into 6 varaibles
    #    - lMean, lStd - Mean and Standard devaition of l channel
    #    - aMean, aStd - Mean and Standard devaition of a channel
    #    - bMean, bStd - Mean and Standard devaition of b channel
    # Write code here
    

    return (lMean, lStd, aMean, aStd, bMean, bStd)

# %%
# This is the main color transfer function
def color_transfer(source_image_name, target_image_name):
    
    
    # STEP - 3: Read image using imread command
    # store the read images into variables names source, target
    # Write code here
    
    
    
    
    # STEP - 4: Convert RGB images to LAB images
    # store the read images into variables names source, target
    # Write code here
    
    
    
    
    
    # STEP - 5: Convert both the LAB images' (source and target) image datatype from np.uint8 to np.float32
    # store the converted images back into the same variables source and target
    # Hint: use astype function from numpy
    # Write code here
    
     
    
    
    # compute color statistics for the source and target images
    # Previous function applied here
    # Do not change this part of the code
    (MeanSrc, lStdSrc, aMeanSrc, aStdSrc, bMeanSrc, bStdSrc) = image_stats(source)
    (lMeanTar, lStdTar, aMeanTar, aStdTar, bMeanTar, bStdTar) = image_stats(target)
 

    
    # STEP - 6: Split target image into three channels - l, a, b
    # Write code here
    
    
    
    # STEP - 7-a: Subtract lMeanTar from channel l and store result back into variable l
    # Write code here
    
    
    # STEP - 7-b: Subtract aMeanTar from channel a and store result back into variable a
    # Write code here
    
    
    # STEP - 7-c: Subtract bMeanTar from channel b and store result back into variable b
    # Write code here
    

    
    # Do not change the code snippet here
    # Scale l channel by the standard deviations
    l = (lStdTar / lStdSrc) * l
    
    
    # STEP - 8-a: Scale channel "a" by the standard deviations
    # Hint: Check operations on l channel
    # Write code here
    

    # STEP - 8-b: Scale channel "b" by the standard deviations
    # Hint: Check operations on l channel
    # Write code here
    

    # STEP - 9-a: Add lMeanSrc to channel l and store result back into variable l
    # Write code here
    
    
    # STEP - 9-b: Add aMeanSrc to channel a and store result back into variable a
    # Write code here
    
    
    # STEP - 9-c: Add bMeanSrc to channel b and store result back into variable b
    # Write code here
    
    
    
    # STEP - 10 : For each channel, l, a, b clip intensities to fall between 0 and 255
    # Hint: Use np.clip() command
    # Store each channels output back to the same variable
    # Write code here
    
    
    

    # STEP - 11: Merge l, a, b channels are store them into variable name transfer
    
    
    
    # STEP - 12: Convert the float type transfer variable to np.uint8 type
    # Hint: use astype function from numpy
    # Write code here
    
    
    
    # STEP -13: Convert transfer image from LAB color space to BGR color space
    # Store the result back in the same "transfer" variable
    # Write code here
    

    return transfer

# %%
# Test 1

img1 = cv2.imread(folder_path + "imgs/chapter3/autumn.jpg", 1);
img2 = cv2.imread(folder_path + "imgs/chapter3/fallingwater.jpg", 1)
out = color_transfer(img1, img2);

plt.figure(figsize=(15, 15))
plt.imshow(out[:,:,::-1])
plt.show()

# %%
# Test 2

img1 = cv2.imread(folder_path + "imgs/chapter3/woods.jpg", 1);
img2 = cv2.imread(folder_path + "imgs/chapter3/storm.jpg", 1)
out = color_transfer(img1, img2);

plt.figure(figsize=(15, 15))
plt.imshow(out[:,:,::-1])
plt.show()

# %%
# Test 3

img1 = cv2.imread(folder_path + "imgs/chapter3/ocean_sunset.jpg", 1);
img2 = cv2.imread(folder_path + "imgs/chapter3/ocean_day.jpg", 1)
out = color_transfer(img1, img2);

plt.figure(figsize=(15, 15))
plt.imshow(out[:,:,::-1])
plt.show()
